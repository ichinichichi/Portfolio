# %% [markdown]
# # Billboard Birthday

# %% [markdown]
# Load the [Python API](https://github.com/guoguo12/billboard-charts) for accessing music charts from Billboard.com.

# %%
#!pip install billboard.py

# %%
# import all the necessary libraries

import billboard
import datetime
import pandas as pd
from datetime import datetime

# %%
# The first item on the list is the number 1 song on the charts
chart = billboard.ChartData('hot-100')
chart[0].artist, chart[0].title, chart[0].weeks
# Out:
# ('BTS', 'Butter', 7)

# %%
[(song.title,song.artist,song.weeks) for song in chart]
# Out:
# [('Butter', 'BTS', 7),
#  ('Good 4 U', 'Olivia Rodrigo', 8),
#  ('Levitating', 'Dua Lipa Featuring DaBaby', 40),
#  ('Kiss Me More', 'Doja Cat Featuring SZA', 13),
#  ('Montero (Call Me By Your Name)', 'Lil Nas X', 15),
#  ('Bad Habits', 'Ed Sheeran', 2),
#  ('Leave The Door Open', 'Silk Sonic (Bruno Mars & Anderson .Paak)', 18),
#  ('Peaches', 'Justin Bieber Featuring Daniel Caesar & Giveon', 16),
#  ('Save Your Tears', 'The Weeknd & Ariana Grande', 30),
#  ('Deja Vu', 'Olivia Rodrigo', 14),
#  ('Astronaut In The Ocean', 'Masked Wolf', 21),
#  ('Rapstar', 'Polo G', 13),
#  ('You Right', 'Doja Cat & The Weeknd', 2),
#  ('Am I The Only One', 'Aaron Lewis', 1),
#  ('Blinding Lights', 'The Weeknd', 83),
#  ('Without You', 'The Kid LAROI', 31),
#  ('Thot Shit', 'Megan Thee Stallion', 4),
#  ('Forever After All', 'Luke Combs', 37),
#  ('Heartbreak Anniversary', 'Giveon', 21),
#  ('Fancy Like', 'Walker Hayes', 3),
#  ('Every Chance I Get', 'DJ Khaled Featuring Lil Baby & Lil Durk', 10),
#  ('Famous Friends', 'Chris Young + Kane Brown', 15),
#  ('Beautiful Mistakes', 'Maroon 5 Featuring Megan Thee Stallion', 18),
#  ('Best Friend', 'Saweetie Featuring Doja Cat', 26),
#  ('Lil Bit', 'Nelly & Florida Georgia Line', 16),
#  ('Single Saturday Night', 'Cole Swindell', 10),
#  ('Heat Waves', 'Glass Animals', 25),
#  ('Leave Before You Love Me', 'Marshmello X Jonas Brothers', 7),
#  ('Wants And Needs', 'Drake Featuring Lil Baby', 18),
#  ('Yonaguni', 'Bad Bunny', 5),
#  ('Blame It On You', 'Jason Aldean', 11),
#  ('Late At Night', 'Roddy Ricch', 5),
#  ('Drivers License', 'Olivia Rodrigo', 26),
#  ('Telepatia', 'Kali Uchis', 20),
#  ('Glad You Exist', 'Dan + Shay', 22),
#  ('Mood', '24kGoldn Featuring iann dior', 48),
#  ('Wockesha', 'Moneybagg Yo', 11),
#  ('Traitor', 'Olivia Rodrigo', 7),
#  ('Todo de Ti', 'Rauw Alejandro', 6),
#  ("Drinkin' Beer. Talkin' God. Amen.",
#   'Chase Rice Featuring Florida Georgia Line',
#   6),
#  ("Ain't Shit", 'Doja Cat', 2),
#  ('pov', 'Ariana Grande', 18),
#  ("My Ex's Best Friend", 'Machine Gun Kelly X blackbear', 47),
#  ('WUSYANAME',
#   'Tyler, The Creator Featuring YoungBoy Never Broke Again & Ty Dolla $ign',
#   2),
#  ('Calling My Phone', 'Lil Tjay Featuring 6LACK', 21),
#  ("Beggin'", 'Maneskin', 2),
#  ('Ball If I Want To', 'DaBaby', 3),
#  ('Gone', 'Dierks Bentley', 17),
#  ('Wasting Time', 'Brent Faiyaz Featuring Drake', 1),
#  ('Red Light Green Light', 'DaBaby', 2),
#  ('Things A Man Oughta Know', 'Lainey Wilson', 8),
#  ('Favorite Crime', 'Olivia Rodrigo', 7),
#  ('Settling Down', 'Miranda Lambert', 17),
#  ('Way Less Sad', 'AJR', 11),
#  ('Straightenin', 'Migos', 8),
#  ('Ski', 'Young Thug & Gunna', 12),
#  ('AM', 'Nio Garcia X J Balvin X Bad Bunny', 2),
#  ('Arcade', 'Duncan Laurence', 13),
#  ('Happier', 'Olivia Rodrigo', 7),
#  ('You', 'Regard x Troye Sivan x Tate McRae', 4),
#  ('my.life', 'J. Cole, 21 Savage & Morray', 8),
#  ('Chasing After You', 'Ryan Hurd With Maren Morris', 10),
#  ("Drunk (And I Don't Wanna Go Home)", 'Elle King & Miranda Lambert', 11),
#  ('Need To Know', 'Doja Cat', 4),
#  ('Track Star', 'Mooski', 20),
#  ('One Too Many', 'Keith Urban Duet With P!nk', 30),
#  ('Hats Off', 'Lil Baby, Lil Durk & Travis Scott', 5),
#  ('Brutal', 'Olivia Rodrigo', 7),
#  ('Build A Bitch', 'Bella Poarch', 8),
#  ("Breaking Up Was Easy In The 90's", 'Sam Hunt', 19),
#  ('Country Again', 'Thomas Rhett', 10),
#  ('Fiel', 'Los Legendarios, Wisin & Jhay Cortez', 4),
#  ('Renegade', 'Big Red Machine Featuring Taylor Swift', 1),
#  ('Waves', 'Luke Bryan', 3),
#  ("We Didn't Have Much", 'Justin Moore', 3),
#  ('Minimum Wage', 'Blake Shelton', 9),
#  ('Follow You', 'Imagine Dragons', 14),
#  ('Jealousy, Jealousy', 'Olivia Rodrigo', 7),
#  ('Come Through', 'H.E.R. Featuring Chris Brown', 5),
#  ('Twerkulator', 'City Girls', 5),
#  ('Cry No More', 'G Herbo Featuring Polo G & Lil Tjay', 1),
#  ('Essence', 'Wizkid Featuring Tems', 1),
#  ('A-O-K', 'Tai Verdes', 1),
#  ('4 Da Gang', '42 Dugg & Roddy Ricch', 13),
#  ('Tombstone', 'Rod Wave', 15),
#  ('Made For You', 'Jake Owen', 20),
#  ('Having Our Way', 'Migos Featuring Drake', 4),
#  ('My Boy', 'Elvie Shane', 2),
#  ('transparentsoul', 'Willow Featuring Travis Barker', 4),
#  ('You Should Probably Leave', 'Chris Stapleton', 1),
#  ('I Was On A Boat That Day', 'Old Dominion', 1),
#  ('Outside', 'MO3 X OG Bobby Billions', 3),
#  ('Working', 'Tate McRae X Khalid', 3),
#  ('Miss The Rage', 'Trippie Redd & Playboi Carti', 9),
#  ('Cold Beer Calling My Name', 'Jameson Rodgers Featuring Luke Combs', 1),
#  ('All I Know So Far', 'P!nk', 4),
#  ("What's Next", 'Drake', 16),
#  ('Enough For You', 'Olivia Rodrigo', 6),
#  ('Juggernaut',
#   'Tyler, The Creator Featuring Lil Uzi Vert & Pharrell Williams',
#   2),
#  ('Tell Em', 'Cochise & $NOT', 4)]

# %%
# create a list of all the dates, Billboard first date goes back to August 4, 1958

dates= pd.date_range(start='1958-8-4',end='2021-7-15',freq='d')
# Out:
# DatetimeIndex(['1958-08-04', '1958-08-05', '1958-08-06', '1958-08-07',
#                '1958-08-08', '1958-08-09', '1958-08-10', '1958-08-11',
#                '1958-08-12', '1958-08-13',
#                ...
#                '2021-07-06', '2021-07-07', '2021-07-08', '2021-07-09',
#                '2021-07-10', '2021-07-11', '2021-07-12', '2021-07-13',
#                '2021-07-14', '2021-07-15'],
#               dtype='datetime64[ns]', length=22992, freq='D')

# %% [markdown]
# ## Scrape only weekly data since Billboard Charts are weekly (faster!)

# %%
#calculate the weekdays for each date

weekday=[d.weekday() for d in dates]

# %%
# turn the dates into strings
dates= [date.strftime("%Y-%m-%d") for date in dates]

# create a Date dataframe with Date and weekday
dfDate={}
dfDate['Date']=dates
dfDate['Weekday']=weekday
dfDate=pd.DataFrame(dfDate)

# %%
weekdate=dfDate[dfDate.Weekday==0].Date

# %%
# how many datapoints do we have for each week?
len(weekdate)

weekdate.isnull().sum()

# reset the index and drop the index
weekdate=weekdate.reset_index().drop('index',axis=1).Date
weekdate
# Out:
# 0       1958-08-04
# 1       1958-08-11
# 2       1958-08-18
# 3       1958-08-25
# 4       1958-09-01
#            ...
# 3280    2021-06-14
# 3281    2021-06-21
# 3282    2021-06-28
# 3283    2021-07-05
# 3284    2021-07-12
# Name: Date, Length: 3285, dtype: object

# %%
# check the data
chart = billboard.ChartData('hot-100', date=weekdate[8])
chart[0]
# Out:
# billboard.ChartEntry(title="It's All In The Game", artist='Tommy Edwards')

# %%
Billboard =[]
for item in weekdate:
    try:
        # we try to grab all the data, as best we can
        d = {}
        chart= billboard.ChartData('hot-100', date=item)
        d['Date'] = item
        d['Artist'] = chart[0].artist
        d['Song'] = chart[0].title
        d['Weeks'] = chart[0].weeks
        print(d)
        Billboard.append(d)
    except:
        # if, for any reason at all, it fails - we quickly save the data
        dfBillboard = pd.DataFrame(Billboard)
        dfBillboard.to_csv('Billboardcharts.csv', index=False)
        raise
dfBillboard = pd.DataFrame(Billboard)
#save it as a csv
dfBillboard.to_csv('Billboardcharts.csv', index=False)
# Out:
# {'Date': '1958-08-04', 'Artist': 'Ricky Nelson', 'Song': 'Poor Little Fool', 'Weeks': 1}
# {'Date': '1958-08-11', 'Artist': 'Ricky Nelson', 'Song': 'Poor Little Fool', 'Weeks': 2}
# {'Date': '1958-08-18', 'Artist': 'Domenico Modugno', 'Song': 'Nel Blu Dipinto Di Blu (Volaré)', 'Weeks': 3}
# {'Date': '1958-08-25', 'Artist': 'The Elegants', 'Song': 'Little Star', 'Weeks': 4}
# {'Date': '1958-09-01', 'Artist': 'Domenico Modugno', 'Song': 'Nel Blu Dipinto Di Blu (Volaré)', 'Weeks': 5}
# {'Date': '1958-09-08', 'Artist': 'Domenico Modugno', 'Song': 'Nel Blu Dipinto Di Blu (Volaré)', 'Weeks': 6}
# {'Date': '1958-09-15', 'Artist': 'Domenico Modugno', 'Song': 'Nel Blu Dipinto Di Blu (Volaré)', 'Weeks': 7}
# {'Date': '1958-09-22', 'Artist': 'Domenico Modugno', 'Song': 'Nel Blu Dipinto Di Blu (Volaré)', 'Weeks': 8}
# {'Date': '1958-09-29', 'Artist': 'Tommy Edwards', 'Song': "It's All In The Game", 'Weeks': 7}
# {'Date': '1958-10-06', 'Artist': 'Tommy Edwards', 'Song': "It's All In The Game", 'Weeks': 8}
# {'Date': '1958-10-13', 'Artist': 'Tommy Edwards', 'Song': "It's All In The Game", 'Weeks': 9}
# {'Date': '1958-10-20', 'Artist': 'Tommy Edwards', 'Song': "It's All In The Game", 'Weeks': 10}
# {'Date': '1958-10-27', 'Artist': 'Tommy Edwards', 'Song': "It's All In The Game", 'Weeks': 11}
# {'Date': '1958-11-03', 'Artist': 'Tommy Edwards', 'Song': "It's All In The Game", 'Weeks': 12}
# {'Date': '1958-11-10', 'Artist': 'Conway Twitty', 'Song': "It's Only Make Believe", 'Weeks': 9}
# {'Date': '1958-11-17', 'Artist': 'The Kingston Trio', 'Song': 'Tom Dooley', 'Weeks': 8}
# {'Date': '1958-11-24', 'Artist': 'Conway Twitty', 'Song': "It's Only Make Believe", 'Weeks': 11}
# {'Date': '1958-12-01', 'Artist': 'The Teddy Bears', 'Song': 'To Know Him, Is To Love Him', 'Weeks': 11}
# {'Date': '1958-12-08', 'Artist': 'The Teddy Bears', 'Song': 'To Know Him, Is To Love Him', 'Weeks': 12}
# {'Date': '1958-12-15', 'Artist': 'The Teddy Bears', 'Song': 'To Know Him, Is To Love Him', 'Weeks': 13}
# {'Date': '1958-12-22', 'Artist': 'The Chipmunks With David Seville', 'Song': 'The Chipmunk Song', 'Weeks': 4}
# {'Date': '1958-12-29', 'Artist': 'The Chipmunks With David Seville', 'Song': 'The Chipmunk Song', 'Weeks': 5}
# {'Date': '1959-01-05', 'Artist': 'The Chipmunks With David Seville', 'Song': 'The Chipmunk Song', 'Weeks': 6}
# {'Date': '1959-01-12', 'Artist': 'The Chipmunks With David Seville', 'Song': 'The Chipmunk Song', 'Weeks': 7}
# {'Date': '1959-01-19', 'Artist': 'The Platters', 'Song': 'Smoke Gets In Your Eyes', 'Weeks': 10}
# {'Date': '1959-01-26', 'Artist': 'The Platters', 'Song': 'Smoke Gets In Your Eyes', 'Weeks': 11}
# {'Date': '1959-02-02', 'Artist': 'The Platters', 'Song': 'Smoke Gets In Your Eyes', 'Weeks': 12}
# {'Date': '1959-02-09', 'Artist': 'Lloyd Price', 'Song': 'Stagger Lee', 'Weeks': 10}
# {'Date': '1959-02-16', 'Artist': 'Lloyd Price', 'Song': 'Stagger Lee', 'Weeks': 11}
# {'Date': '1959-02-23', 'Artist': 'Lloyd Price', 'Song': 'Stagger Lee', 'Weeks': 12}
# {'Date': '1959-03-02', 'Artist': 'Lloyd Price', 'Song': 'Stagger Lee', 'Weeks': 13}
# {'Date': '1959-03-09', 'Artist': 'Frankie Avalon', 'Song': 'Venus', 'Weeks': 5}
# {'Date': '1959-03-16', 'Artist': 'Frankie Avalon', 'Song': 'Venus', 'Weeks': 6}
# {'Date': '1959-03-23', 'Artist': 'Frankie Avalon', 'Song': 'Venus', 'Weeks': 7}
# {'Date': '1959-03-30', 'Artist': 'Frankie Avalon', 'Song': 'Venus', 'Weeks': 8}
# {'Date': '1959-04-06', 'Artist': 'Frankie Avalon', 'Song': 'Venus', 'Weeks': 9}
# {'Date': '1959-04-13', 'Artist': 'The Fleetwoods', 'Song': 'Come Softly To Me', 'Weeks': 6}
# {'Date': '1959-04-20', 'Artist': 'The Fleetwoods', 'Song': 'Come Softly To Me', 'Weeks': 7}
# {'Date': '1959-04-27', 'Artist': 'The Fleetwoods', 'Song': 'Come Softly To Me', 'Weeks': 8}
# {'Date': '1959-05-04', 'Artist': 'The Fleetwoods', 'Song': 'Come Softly To Me', 'Weeks': 9}
# {'Date': '1959-05-11', 'Artist': 'Dave "Baby" Cortez', 'Song': 'The Happy Organ', 'Weeks': 9}
# {'Date': '1959-05-18', 'Artist': 'Wilbert Harrison', 'Song': 'Kansas City', 'Weeks': 6}
# {'Date': '1959-05-25', 'Artist': 'Wilbert Harrison', 'Song': 'Kansas City', 'Weeks': 7}
# {'Date': '1959-06-01', 'Artist': 'Johnny Horton', 'Song': 'The Battle Of New Orleans', 'Weeks': 6}
# {'Date': '1959-06-08', 'Artist': 'Johnny Horton', 'Song': 'The Battle Of New Orleans', 'Weeks': 7}
# {'Date': '1959-06-15', 'Artist': 'Johnny Horton', 'Song': 'The Battle Of New Orleans', 'Weeks': 8}
# {'Date': '1959-06-22', 'Artist': 'Johnny Horton', 'Song': 'The Battle Of New Orleans', 'Weeks': 9}
# {'Date': '1959-06-29', 'Artist': 'Johnny Horton', 'Song': 'The Battle Of New Orleans', 'Weeks': 10}
# {'Date': '1959-07-06', 'Artist': 'Johnny Horton', 'Song': 'The Battle Of New Orleans', 'Weeks': 11}
# {'Date': '1959-07-13', 'Artist': 'Paul Anka', 'Song': 'Lonely Boy', 'Weeks': 7}
# {'Date': '1959-07-20', 'Artist': 'Paul Anka', 'Song': 'Lonely Boy', 'Weeks': 8}
# {'Date': '1959-07-27', 'Artist': 'Paul Anka', 'Song': 'Lonely Boy', 'Weeks': 9}
# {'Date': '1959-08-03', 'Artist': 'Paul Anka', 'Song': 'Lonely Boy', 'Weeks': 10}
# {'Date': '1959-08-10', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': "A Big Hunk O' Love", 'Weeks': 6}
# {'Date': '1959-08-17', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': "A Big Hunk O' Love", 'Weeks': 7}
# {'Date': '1959-08-24', 'Artist': 'The Browns', 'Song': 'The Three Bells', 'Weeks': 5}
# {'Date': '1959-08-31', 'Artist': 'The Browns', 'Song': 'The Three Bells', 'Weeks': 6}
# {'Date': '1960-03-14', 'Artist': 'Percy Faith And His Orchestra', 'Song': 'The Theme From "A Summer Place"', 'Weeks': 10}
# {'Date': '1960-03-21', 'Artist': 'Percy Faith And His Orchestra', 'Song': 'The Theme From "A Summer Place"', 'Weeks': 11}
# {'Date': '1960-03-28', 'Artist': 'Percy Faith And His Orchestra', 'Song': 'The Theme From "A Summer Place"', 'Weeks': 12}
# {'Date': '1960-04-04', 'Artist': 'Percy Faith And His Orchestra', 'Song': 'The Theme From "A Summer Place"', 'Weeks': 13}
# {'Date': '1960-04-11', 'Artist': 'Percy Faith And His Orchestra', 'Song': 'The Theme From "A Summer Place"', 'Weeks': 14}
# {'Date': '1960-04-18', 'Artist': 'Percy Faith And His Orchestra', 'Song': 'The Theme From "A Summer Place"', 'Weeks': 15}
# {'Date': '1960-04-25', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': 'Stuck On You', 'Weeks': 4}
# {'Date': '1960-05-02', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': 'Stuck On You', 'Weeks': 5}
# {'Date': '1960-05-09', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': 'Stuck On You', 'Weeks': 6}
# {'Date': '1960-05-16', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': 'Stuck On You', 'Weeks': 7}
# {'Date': '1960-05-23', 'Artist': 'The Everly Brothers', 'Song': "Cathy's Clown", 'Weeks': 6}
# {'Date': '1960-05-30', 'Artist': 'The Everly Brothers', 'Song': "Cathy's Clown", 'Weeks': 7}
# {'Date': '1960-06-06', 'Artist': 'The Everly Brothers', 'Song': "Cathy's Clown", 'Weeks': 8}
# {'Date': '1960-06-13', 'Artist': 'The Everly Brothers', 'Song': "Cathy's Clown", 'Weeks': 9}
# {'Date': '1960-06-20', 'Artist': 'The Everly Brothers', 'Song': "Cathy's Clown", 'Weeks': 10}
# {'Date': '1960-06-27', 'Artist': 'Connie Francis', 'Song': "Everybody's Somebody's Fool", 'Weeks': 8}
# {'Date': '1960-07-04', 'Artist': 'Connie Francis', 'Song': "Everybody's Somebody's Fool", 'Weeks': 9}
# {'Date': '1960-07-11', 'Artist': 'Hollywood Argyles', 'Song': 'Alley-Oop', 'Weeks': 7}
# {'Date': '1960-07-18', 'Artist': 'Brenda Lee', 'Song': "I'm Sorry", 'Weeks': 8}
# {'Date': '1960-07-25', 'Artist': 'Brenda Lee', 'Song': "I'm Sorry", 'Weeks': 9}
# {'Date': '1960-08-01', 'Artist': 'Brenda Lee', 'Song': "I'm Sorry", 'Weeks': 10}
# {'Date': '1960-08-08', 'Artist': 'Brian Hyland', 'Song': 'Itsy Bitsy Teenie Weenie Yellow Polkadot Bikini', 'Weeks': 6}
# {'Date': '1960-08-15', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': "It's Now Or Never", 'Weeks': 5}
# {'Date': '1960-08-22', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': "It's Now Or Never", 'Weeks': 6}
# {'Date': '1960-08-29', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': "It's Now Or Never", 'Weeks': 7}
# {'Date': '1961-02-20', 'Artist': 'Lawrence Welk And His Orchestra', 'Song': 'Calcutta', 'Weeks': 11}
# {'Date': '1961-02-27', 'Artist': 'Chubby Checker', 'Song': 'Pony Time', 'Weeks': 6}
# {'Date': '1961-03-06', 'Artist': 'Chubby Checker', 'Song': 'Pony Time', 'Weeks': 7}
# {'Date': '1961-03-13', 'Artist': 'Chubby Checker', 'Song': 'Pony Time', 'Weeks': 8}
# {'Date': '1961-03-20', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': 'Surrender', 'Weeks': 5}
# {'Date': '1961-03-27', 'Artist': 'Elvis Presley With The Jordanaires', 'Song': 'Surrender', 'Weeks': 6}
# {'Date': '1961-04-03', 'Artist': 'The Marcels', 'Song': 'Blue Moon', 'Weeks': 5}
# {'Date': '1961-04-10', 'Artist': 'The Marcels', 'Song': 'Blue Moon', 'Weeks': 6}
# {'Date': '1961-04-17', 'Artist': 'The Marcels', 'Song': 'Blue Moon', 'Weeks': 7}
# {'Date': '1961-04-24', 'Artist': 'Del Shannon', 'Song': 'Runaway', 'Weeks': 8}
# {'Date': '1961-05-01', 'Artist': 'Del Shannon', 'Song': 'Runaway', 'Weeks': 9}
# {'Date': '1961-05-08', 'Artist': 'Del Shannon', 'Song': 'Runaway', 'Weeks': 10}
# {'Date': '1961-05-15', 'Artist': 'Del Shannon', 'Song': 'Runaway', 'Weeks': 11}
# {'Date': '1961-05-22', 'Artist': 'Ernie K-Doe', 'Song': 'Mother-In-Law', 'Weeks': 9}
# {'Date': '1961-05-29', 'Artist': 'Ricky Nelson', 'Song': "Travelin' Man", 'Weeks': 6}
# {'Date': '1961-06-05', 'Artist': 'Roy Orbison', 'Song': 'Running Scared', 'Weeks': 9}
# {'Date': '1961-06-12', 'Artist': 'Ricky Nelson', 'Song': "Travelin' Man", 'Weeks': 8}
# {'Date': '1961-06-19', 'Artist': 'Pat Boone', 'Song': 'Moody River', 'Weeks': 8}
# {'Date': '1961-06-26', 'Artist': 'U.S. Bonds', 'Song': 'Quarter To Three', 'Weeks': 6}
# {'Date': '1961-07-03', 'Artist': 'U.S. Bonds', 'Song': 'Quarter To Three', 'Weeks': 7}
# {'Date': '1961-07-10', 'Artist': 'Bobby Lewis', 'Song': "Tossin' And Turnin'", 'Weeks': 12}
# {'Date': '1961-07-17', 'Artist': 'Bobby Lewis', 'Song': "Tossin' And Turnin'", 'Weeks': 13}
# {'Date': '1961-07-24', 'Artist': 'Bobby Lewis', 'Song': "Tossin' And Turnin'", 'Weeks': 14}
# {'Date': '1961-07-31', 'Artist': 'Bobby Lewis', 'Song': "Tossin' And Turnin'", 'Weeks': 15}
# {'Date': '1961-08-07', 'Artist': 'Bobby Lewis', 'Song': "Tossin' And Turnin'", 'Weeks': 16}
# {'Date': '1961-08-14', 'Artist': 'Bobby Lewis', 'Song': "Tossin' And Turnin'", 'Weeks': 17}
# {'Date': '1961-08-21', 'Artist': 'Bobby Lewis', 'Song': "Tossin' And Turnin'", 'Weeks': 18}
# {'Date': '1961-08-28', 'Artist': 'Joe Dowell', 'Song': 'Wooden Heart', 'Weeks': 10}
# {'Date': '1961-09-04', 'Artist': 'The Highwaymen', 'Song': 'Michael', 'Weeks': 9}
# {'Date': '1961-09-11', 'Artist': 'The Highwaymen', 'Song': 'Michael', 'Weeks': 10}
# {'Date': '1961-09-18', 'Artist': 'Bobby Vee', 'Song': 'Take Good Care Of My Baby', 'Weeks': 7}
# {'Date': '1961-09-25', 'Artist': 'Bobby Vee', 'Song': 'Take Good Care Of My Baby', 'Weeks': 8}
# {'Date': '1961-10-02', 'Artist': 'Bobby Vee', 'Song': 'Take Good Care Of My Baby', 'Weeks': 9}
# {'Date': '1961-10-09', 'Artist': 'Ray Charles and his Orchestra', 'Song': 'Hit The Road Jack', 'Weeks': 5}
# {'Date': '1961-10-16', 'Artist': 'Ray Charles and his Orchestra', 'Song': 'Hit The Road Jack', 'Weeks': 6}
# {'Date': '1961-10-23', 'Artist': 'Dion', 'Song': 'Runaround Sue', 'Weeks': 5}
# {'Date': '1961-10-30', 'Artist': 'Dion', 'Song': 'Runaround Sue', 'Weeks': 6}
# {'Date': '1961-11-06', 'Artist': 'Jimmy Dean', 'Song': 'Big Bad John', 'Weeks': 6}
# {'Date': '1961-11-13', 'Artist': 'Jimmy Dean', 'Song': 'Big Bad John', 'Weeks': 7}
# {'Date': '1961-11-20', 'Artist': 'Jimmy Dean', 'Song': 'Big Bad John', 'Weeks': 8}
# {'Date': '1961-11-27', 'Artist': 'Jimmy Dean', 'Song': 'Big Bad John', 'Weeks': 9}
# {'Date': '1961-12-04', 'Artist': 'Jimmy Dean', 'Song': 'Big Bad John', 'Weeks': 10}
# {'Date': '1961-12-11', 'Artist': 'The Marvelettes', 'Song': 'Please Mr. Postman', 'Weeks': 15}
# {'Date': '1961-12-18', 'Artist': 'The Tokens', 'Song': 'The Lion Sleeps Tonight', 'Weeks': 6}
# {'Date': '1961-12-25', 'Artist': 'The Tokens', 'Song': 'The Lion Sleeps Tonight', 'Weeks': 7}
# {'Date': '1962-01-01', 'Artist': 'The Tokens', 'Song': 'The Lion Sleeps Tonight', 'Weeks': 8}
# {'Date': '1962-01-08', 'Artist': 'Chubby Checker', 'Song': 'The Twist', 'Weeks': 27}
# {'Date': '1962-01-15', 'Artist': 'Chubby Checker', 'Song': 'The Twist', 'Weeks': 28}
# {'Date': '1962-01-22', 'Artist': 'Joey Dee & the Starliters', 'Song': 'Peppermint Twist - Part I', 'Weeks': 10}
# {'Date': '1962-01-29', 'Artist': 'Joey Dee & the Starliters', 'Song': 'Peppermint Twist - Part I', 'Weeks': 11}
# {'Date': '1962-02-05', 'Artist': 'Joey Dee & the Starliters', 'Song': 'Peppermint Twist - Part I', 'Weeks': 12}
# {'Date': '1962-02-12', 'Artist': 'Gene Chandler', 'Song': 'Duke Of Earl', 'Weeks': 6}
# {'Date': '1962-02-19', 'Artist': 'Gene Chandler', 'Song': 'Duke Of Earl', 'Weeks': 7}
# {'Date': '1962-02-26', 'Artist': 'Gene Chandler', 'Song': 'Duke Of Earl', 'Weeks': 8}
# {'Date': '1962-09-03', 'Artist': 'Tommy Roe', 'Song': 'Sheila', 'Weeks': 7}
# {'Date': '1962-09-10', 'Artist': 'The 4 Seasons', 'Song': 'Sherry', 'Weeks': 4}
# {'Date': '1962-09-17', 'Artist': 'The 4 Seasons', 'Song': 'Sherry', 'Weeks': 5}
# {'Date': '1962-09-24', 'Artist': 'The 4 Seasons', 'Song': 'Sherry', 'Weeks': 6}
# {'Date': '1962-10-01', 'Artist': 'The 4 Seasons', 'Song': 'Sherry', 'Weeks': 7}
# {'Date': '1962-10-08', 'Artist': 'The 4 Seasons', 'Song': 'Sherry', 'Weeks': 8}
# {'Date': '1962-10-15', 'Artist': 'Bobby "Boris" Pickett And The Crypt-Kickers', 'Song': 'Monster Mash', 'Weeks': 7}
# {'Date': '1962-10-22', 'Artist': 'Bobby "Boris" Pickett And The Crypt-Kickers', 'Song': 'Monster Mash', 'Weeks': 8}
# {'Date': '1962-10-29', 'Artist': 'The Crystals', 'Song': "He's A Rebel", 'Weeks': 9}
# {'Date': '1962-11-05', 'Artist': 'The Crystals', 'Song': "He's A Rebel", 'Weeks': 10}
# {'Date': '1962-11-12', 'Artist': 'The 4 Seasons', 'Song': "Big Girls Don't Cry", 'Weeks': 5}
# {'Date': '1962-11-19', 'Artist': 'The 4 Seasons', 'Song': "Big Girls Don't Cry", 'Weeks': 6}
# {'Date': '1962-11-26', 'Artist': 'The 4 Seasons', 'Song': "Big Girls Don't Cry", 'Weeks': 7}
# {'Date': '1962-12-03', 'Artist': 'The 4 Seasons', 'Song': "Big Girls Don't Cry", 'Weeks': 8}
# {'Date': '1962-12-10', 'Artist': 'The 4 Seasons', 'Song': "Big Girls Don't Cry", 'Weeks': 9}
# {'Date': '1962-12-17', 'Artist': 'The Tornadoes', 'Song': 'Telstar', 'Weeks': 8}
# {'Date': '1962-12-24', 'Artist': 'The Tornadoes', 'Song': 'Telstar', 'Weeks': 9}
# {'Date': '1962-12-31', 'Artist': 'The Tornadoes', 'Song': 'Telstar', 'Weeks': 10}
# {'Date': '1963-01-07', 'Artist': 'Steve Lawrence', 'Song': 'Go Away Little Girl', 'Weeks': 10}
# {'Date': '1963-01-14', 'Artist': 'Steve Lawrence', 'Song': 'Go Away Little Girl', 'Weeks': 11}
# {'Date': '1963-01-21', 'Artist': 'The Rooftop Singers', 'Song': 'Walk Right In', 'Weeks': 4}
# {'Date': '1963-01-28', 'Artist': 'The Rooftop Singers', 'Song': 'Walk Right In', 'Weeks': 5}
# {'Date': '1963-02-04', 'Artist': 'Paul and Paula', 'Song': 'Hey Paula', 'Weeks': 7}
# {'Date': '1963-02-11', 'Artist': 'Paul and Paula', 'Song': 'Hey Paula', 'Weeks': 8}
# {'Date': '1963-02-18', 'Artist': 'Paul and Paula', 'Song': 'Hey Paula', 'Weeks': 9}
# {'Date': '1963-02-25', 'Artist': 'The 4 Seasons', 'Song': 'Walk Like A Man', 'Weeks': 6}
# {'Date': '1963-03-04', 'Artist': 'The 4 Seasons', 'Song': 'Walk Like A Man', 'Weeks': 7}
# {'Date': '1963-03-11', 'Artist': 'The 4 Seasons', 'Song': 'Walk Like A Man', 'Weeks': 8}
# {'Date': '1963-03-18', 'Artist': 'Ruby And The Romantics', 'Song': 'Our Day Will Come', 'Weeks': 7}
# {'Date': '1963-03-25', 'Artist': 'The Chiffons', 'Song': "He's So Fine", 'Weeks': 6}
# {'Date': '1963-04-01', 'Artist': 'The Chiffons', 'Song': "He's So Fine", 'Weeks': 7}
# {'Date': '1963-04-08', 'Artist': 'The Chiffons', 'Song': "He's So Fine", 'Weeks': 8}
# {'Date': '1963-04-15', 'Artist': 'The Chiffons', 'Song': "He's So Fine", 'Weeks': 9}
# {'Date': '1963-04-22', 'Artist': 'Little Peggy March', 'Song': 'I Will Follow Him', 'Weeks': 6}
# {'Date': '1963-04-29', 'Artist': 'Little Peggy March', 'Song': 'I Will Follow Him', 'Weeks': 7}
# {'Date': '1963-05-06', 'Artist': 'Little Peggy March', 'Song': 'I Will Follow Him', 'Weeks': 8}
# {'Date': '1963-05-13', 'Artist': 'Jimmy Soul', 'Song': 'If You Wanna Be Happy', 'Weeks': 8}
# {'Date': '1963-05-20', 'Artist': 'Jimmy Soul', 'Song': 'If You Wanna Be Happy', 'Weeks': 9}
# {'Date': '1963-05-27', 'Artist': 'Lesley Gore', 'Song': "It's My Party", 'Weeks': 4}
# {'Date': '1963-06-03', 'Artist': 'Lesley Gore', 'Song': "It's My Party", 'Weeks': 5}
# {'Date': '1963-06-10', 'Artist': 'Kyu Sakamoto', 'Song': 'Sukiyaki', 'Weeks': 6}
# {'Date': '1963-06-17', 'Artist': 'Kyu Sakamoto', 'Song': 'Sukiyaki', 'Weeks': 7}
# {'Date': '1963-06-24', 'Artist': 'Kyu Sakamoto', 'Song': 'Sukiyaki', 'Weeks': 8}
# {'Date': '1963-07-01', 'Artist': 'The Essex', 'Song': 'Easier Said Than Done', 'Weeks': 5}
# {'Date': '1963-07-08', 'Artist': 'The Essex', 'Song': 'Easier Said Than Done', 'Weeks': 6}
# {'Date': '1963-07-15', 'Artist': 'Jan & Dean', 'Song': 'Surf City', 'Weeks': 6}
# {'Date': '1963-07-22', 'Artist': 'Jan & Dean', 'Song': 'Surf City', 'Weeks': 7}
# {'Date': '1963-07-29', 'Artist': 'The Tymes', 'Song': 'So Much In Love', 'Weeks': 10}
# {'Date': '1963-08-05', 'Artist': 'Little Stevie Wonder', 'Song': 'Fingertips - Pt 2', 'Weeks': 8}
# {'Date': '1963-08-12', 'Artist': 'Little Stevie Wonder', 'Song': 'Fingertips - Pt 2', 'Weeks': 9}
# {'Date': '1963-08-19', 'Artist': 'Little Stevie Wonder', 'Song': 'Fingertips - Pt 2', 'Weeks': 10}
# {'Date': '1963-08-26', 'Artist': 'The Angels', 'Song': "My Boyfriend's Back", 'Weeks': 5}
# {'Date': '1963-09-02', 'Artist': 'The Angels', 'Song': "My Boyfriend's Back", 'Weeks': 6}
# {'Date': '1963-09-09', 'Artist': 'The Angels', 'Song': "My Boyfriend's Back", 'Weeks': 7}
# {'Date': '1964-09-14', 'Artist': 'The Animals', 'Song': 'House Of The Rising Sun', 'Weeks': 7}
# {'Date': '1964-09-21', 'Artist': 'Roy Orbison And The Candy Men', 'Song': 'Oh, Pretty Woman', 'Weeks': 5}
# {'Date': '1964-09-28', 'Artist': 'Roy Orbison And The Candy Men', 'Song': 'Oh, Pretty Woman', 'Weeks': 6}
# {'Date': '1964-10-05', 'Artist': 'Roy Orbison And The Candy Men', 'Song': 'Oh, Pretty Woman', 'Weeks': 7}
# {'Date': '1964-10-12', 'Artist': 'Manfred Mann', 'Song': 'Do Wah Diddy Diddy', 'Weeks': 7}
# {'Date': '1964-10-19', 'Artist': 'Manfred Mann', 'Song': 'Do Wah Diddy Diddy', 'Weeks': 8}
# {'Date': '1964-10-26', 'Artist': 'The Supremes', 'Song': 'Baby Love', 'Weeks': 5}
# {'Date': '1964-11-02', 'Artist': 'The Supremes', 'Song': 'Baby Love', 'Weeks': 6}
# {'Date': '1964-11-09', 'Artist': 'The Supremes', 'Song': 'Baby Love', 'Weeks': 7}
# {'Date': '1964-11-16', 'Artist': 'The Supremes', 'Song': 'Baby Love', 'Weeks': 8}
# {'Date': '1964-11-23', 'Artist': 'The Shangri-Las', 'Song': 'Leader Of The Pack', 'Weeks': 8}
# {'Date': '1964-11-30', 'Artist': 'Lorne Greene', 'Song': 'Ringo', 'Weeks': 6}
# {'Date': '1964-12-07', 'Artist': 'Bobby Vinton', 'Song': 'Mr. Lonely', 'Weeks': 7}
# {'Date': '1964-12-14', 'Artist': 'The Supremes', 'Song': 'Come See About Me', 'Weeks': 6}
# {'Date': '1964-12-21', 'Artist': 'The Beatles', 'Song': 'I Feel Fine', 'Weeks': 4}
# {'Date': '1964-12-28', 'Artist': 'The Beatles', 'Song': 'I Feel Fine', 'Weeks': 5}
# {'Date': '1965-01-04', 'Artist': 'The Beatles', 'Song': 'I Feel Fine', 'Weeks': 6}
# {'Date': '1965-01-11', 'Artist': 'The Supremes', 'Song': 'Come See About Me', 'Weeks': 10}
# {'Date': '1965-01-18', 'Artist': 'Petula Clark', 'Song': 'Downtown', 'Weeks': 6}
# {'Date': '1965-01-25', 'Artist': 'Petula Clark', 'Song': 'Downtown', 'Weeks': 7}
# {'Date': '1965-02-01', 'Artist': 'The Righteous Brothers', 'Song': "You've Lost That Lovin' Feelin'", 'Weeks': 9}
# {'Date': '1965-02-08', 'Artist': 'The Righteous Brothers', 'Song': "You've Lost That Lovin' Feelin'", 'Weeks': 10}
# {'Date': '1965-02-15', 'Artist': 'Gary Lewis And The Playboys', 'Song': 'This Diamond Ring', 'Weeks': 6}
# {'Date': '1965-02-22', 'Artist': 'Gary Lewis And The Playboys', 'Song': 'This Diamond Ring', 'Weeks': 7}
# {'Date': '1965-03-01', 'Artist': 'The Temptations', 'Song': 'My Girl', 'Weeks': 8}
# {'Date': '1965-03-08', 'Artist': 'The Beatles', 'Song': 'Eight Days A Week', 'Weeks': 4}
# {'Date': '1967-03-20', 'Artist': 'The Turtles', 'Song': 'Happy Together', 'Weeks': 7}
# {'Date': '1967-03-27', 'Artist': 'The Turtles', 'Song': 'Happy Together', 'Weeks': 8}
# {'Date': '1967-04-03', 'Artist': 'The Turtles', 'Song': 'Happy Together', 'Weeks': 9}
# {'Date': '1967-04-10', 'Artist': 'Nancy Sinatra & Frank Sinatra', 'Song': "Somethin' Stupid", 'Weeks': 5}
# {'Date': '1967-04-17', 'Artist': 'Nancy Sinatra & Frank Sinatra', 'Song': "Somethin' Stupid", 'Weeks': 6}
# {'Date': '1967-04-24', 'Artist': 'Nancy Sinatra & Frank Sinatra', 'Song': "Somethin' Stupid", 'Weeks': 7}
# {'Date': '1967-05-01', 'Artist': 'Nancy Sinatra & Frank Sinatra', 'Song': "Somethin' Stupid", 'Weeks': 8}
# {'Date': '1967-05-08', 'Artist': 'The Supremes', 'Song': 'The Happening', 'Weeks': 6}
# {'Date': '1967-05-15', 'Artist': 'The Young Rascals', 'Song': "Groovin'", 'Weeks': 5}
# {'Date': '1967-05-22', 'Artist': 'The Young Rascals', 'Song': "Groovin'", 'Weeks': 6}
# {'Date': '1967-05-29', 'Artist': 'Aretha Franklin', 'Song': 'Respect', 'Weeks': 6}
# {'Date': '1967-06-05', 'Artist': 'Aretha Franklin', 'Song': 'Respect', 'Weeks': 7}
# {'Date': '1967-06-12', 'Artist': 'The Young Rascals', 'Song': "Groovin'", 'Weeks': 9}
# {'Date': '1967-06-19', 'Artist': 'The Young Rascals', 'Song': "Groovin'", 'Weeks': 10}
# {'Date': '1967-06-26', 'Artist': 'The Association', 'Song': 'Windy', 'Weeks': 6}
# {'Date': '1967-07-03', 'Artist': 'The Association', 'Song': 'Windy', 'Weeks': 7}
# {'Date': '1967-07-10', 'Artist': 'The Association', 'Song': 'Windy', 'Weeks': 8}
# {'Date': '1967-07-17', 'Artist': 'The Association', 'Song': 'Windy', 'Weeks': 9}
# {'Date': '1967-07-24', 'Artist': 'The Doors', 'Song': 'Light My Fire', 'Weeks': 9}
# {'Date': '1967-07-31', 'Artist': 'The Doors', 'Song': 'Light My Fire', 'Weeks': 10}
# {'Date': '1967-08-07', 'Artist': 'The Doors', 'Song': 'Light My Fire', 'Weeks': 11}
# {'Date': '1967-08-14', 'Artist': 'The Beatles', 'Song': 'All You Need Is Love', 'Weeks': 5}
# {'Date': '1967-08-21', 'Artist': 'Bobbie Gentry', 'Song': 'Ode To Billie Joe', 'Weeks': 4}
# {'Date': '1967-08-28', 'Artist': 'Bobbie Gentry', 'Song': 'Ode To Billie Joe', 'Weeks': 5}
# {'Date': '1967-09-04', 'Artist': 'Bobbie Gentry', 'Song': 'Ode To Billie Joe', 'Weeks': 6}
# {'Date': '1967-09-11', 'Artist': 'Bobbie Gentry', 'Song': 'Ode To Billie Joe', 'Weeks': 7}
# {'Date': '1967-09-18', 'Artist': 'The Box Tops', 'Song': 'The Letter', 'Weeks': 7}
# {'Date': '1967-09-25', 'Artist': 'The Box Tops', 'Song': 'The Letter', 'Weeks': 8}
# {'Date': '2014-11-10', 'Artist': 'Taylor Swift', 'Song': 'Shake It Off', 'Weeks': 11}
# {'Date': '2014-11-17', 'Artist': 'Taylor Swift', 'Song': 'Shake It Off', 'Weeks': 12}
# {'Date': '2014-11-24', 'Artist': 'Taylor Swift', 'Song': 'Blank Space', 'Weeks': 3}
# {'Date': '2014-12-01', 'Artist': 'Taylor Swift', 'Song': 'Blank Space', 'Weeks': 4}
# {'Date': '2014-12-08', 'Artist': 'Taylor Swift', 'Song': 'Blank Space', 'Weeks': 5}
# {'Date': '2014-12-15', 'Artist': 'Taylor Swift', 'Song': 'Blank Space', 'Weeks': 6}
# {'Date': '2014-12-22', 'Artist': 'Taylor Swift', 'Song': 'Blank Space', 'Weeks': 7}
# {'Date': '2014-12-29', 'Artist': 'Taylor Swift', 'Song': 'Blank Space', 'Weeks': 8}
# {'Date': '2015-01-05', 'Artist': 'Taylor Swift', 'Song': 'Blank Space', 'Weeks': 9}
# {'Date': '2015-01-12', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 8}
# {'Date': '2015-01-19', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 9}
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\AppData\Local\Programs\Python\Python38\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000024C68EF39D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='www.billboard.com', port=443): Max retries exceeded with url: /charts/hot-100/2015-01-26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C68EF39D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-114-56d782c81c66> in <module>
#       4         # we try to grab all the data, as best we can
#       5         d = {}
# ----> 6         chart= billboard.ChartData('hot-100', date=item)
#       7         d['Date'] = item
#       8         d['Artist'] = chart[0].artist
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\billboard.py in __init__(self, name, date, year, fetch, max_retries, timeout)
#     188         self.entries = []
#     189         if fetch:
# --> 190             self.fetchEntries()
#     191
#     192     def __repr__(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\billboard.py in fetchEntries(self)
#     478
#     479         session = _get_session_with_retries(max_retries=self._max_retries)
# --> 480         req = session.get(url, timeout=self._timeout)
#     481         if req.status_code == 404:
#     482             message = "Chart not found (perhaps the name is misspelled?)"
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.billboard.com', port=443): Max retries exceeded with url: /charts/hot-100/2015-01-26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C68EF39D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %% [markdown]
# ## Run this code when the scraping stops at a specific date

# %%
# convert the weekdates back to datetime format 
#'2015-01-19'

formatweekdate=[datetime.fromisoformat(date) for date in weekdate]
# Out:
# [datetime.datetime(1958, 8, 4, 0, 0),
#  datetime.datetime(1958, 8, 11, 0, 0),
#  datetime.datetime(1958, 8, 18, 0, 0),
#  datetime.datetime(1958, 8, 25, 0, 0),
#  datetime.datetime(1958, 9, 1, 0, 0),
#  datetime.datetime(1958, 9, 8, 0, 0),
#  datetime.datetime(1958, 9, 15, 0, 0),
#  datetime.datetime(1958, 9, 22, 0, 0),
#  datetime.datetime(1958, 9, 29, 0, 0),
#  datetime.datetime(1958, 10, 6, 0, 0),
#  datetime.datetime(1958, 10, 13, 0, 0),
#  datetime.datetime(1958, 10, 20, 0, 0),
#  datetime.datetime(1958, 10, 27, 0, 0),
#  datetime.datetime(1958, 11, 3, 0, 0),
#  datetime.datetime(1958, 11, 10, 0, 0),
#  datetime.datetime(1958, 11, 17, 0, 0),
#  datetime.datetime(1958, 11, 24, 0, 0),
#  datetime.datetime(1958, 12, 1, 0, 0),
#  datetime.datetime(1958, 12, 8, 0, 0),
#  datetime.datetime(1958, 12, 15, 0, 0),
#  datetime.datetime(1958, 12, 22, 0, 0),
#  datetime.datetime(1958, 12, 29, 0, 0),
#  datetime.datetime(1959, 1, 5, 0, 0),
#  datetime.datetime(1959, 1, 12, 0, 0),
#  datetime.datetime(1959, 1, 19, 0, 0),
#  datetime.datetime(1959, 1, 26, 0, 0),
#  datetime.datetime(1959, 2, 2, 0, 0),
#  datetime.datetime(1959, 2, 9, 0, 0),
#  datetime.datetime(1959, 2, 16, 0, 0),
#  datetime.datetime(1959, 2, 23, 0, 0),
#  datetime.datetime(1959, 3, 2, 0, 0),
#  datetime.datetime(1959, 3, 9, 0, 0),
#  datetime.datetime(1959, 3, 16, 0, 0),
#  datetime.datetime(1959, 3, 23, 0, 0),
#  datetime.datetime(1959, 3, 30, 0, 0),
#  datetime.datetime(1959, 4, 6, 0, 0),
#  datetime.datetime(1959, 4, 13, 0, 0),
#  datetime.datetime(1959, 4, 20, 0, 0),
#  datetime.datetime(1959, 4, 27, 0, 0),
#  datetime.datetime(1959, 5, 4, 0, 0),
#  datetime.datetime(1959, 5, 11, 0, 0),
#  datetime.datetime(1959, 5, 18, 0, 0),
#  datetime.datetime(1959, 5, 25, 0, 0),
#  datetime.datetime(1959, 6, 1, 0, 0),
#  datetime.datetime(1959, 6, 8, 0, 0),
#  datetime.datetime(1959, 6, 15, 0, 0),
#  datetime.datetime(1959, 6, 22, 0, 0),
#  datetime.datetime(1959, 6, 29, 0, 0),
#  datetime.datetime(1959, 7, 6, 0, 0),
#  datetime.datetime(1959, 7, 13, 0, 0),
#  datetime.datetime(1959, 7, 20, 0, 0),
#  datetime.datetime(1959, 7, 27, 0, 0),
#  datetime.datetime(1959, 8, 3, 0, 0),
#  datetime.datetime(1959, 8, 10, 0, 0),
#  datetime.datetime(1959, 8, 17, 0, 0),
#  datetime.datetime(1959, 8, 24, 0, 0),
#  datetime.datetime(1959, 8, 31, 0, 0),
#  datetime.datetime(1959, 9, 7, 0, 0),
#  datetime.datetime(1959, 9, 14, 0, 0),
#  datetime.datetime(1959, 9, 21, 0, 0),
#  datetime.datetime(1959, 9, 28, 0, 0),
#  datetime.datetime(1959, 10, 5, 0, 0),
#  datetime.datetime(1959, 10, 12, 0, 0),
#  datetime.datetime(1959, 10, 19, 0, 0),
#  datetime.datetime(1959, 10, 26, 0, 0),
#  datetime.datetime(1959, 11, 2, 0, 0),
#  datetime.datetime(1959, 11, 9, 0, 0),
#  datetime.datetime(1959, 11, 16, 0, 0),
#  datetime.datetime(1959, 11, 23, 0, 0),
#  datetime.datetime(1959, 11, 30, 0, 0),
#  datetime.datetime(1959, 12, 7, 0, 0),
#  datetime.datetime(1959, 12, 14, 0, 0),
#  datetime.datetime(1959, 12, 21, 0, 0),
#  datetime.datetime(1959, 12, 28, 0, 0),
#  datetime.datetime(1960, 1, 4, 0, 0),
#  datetime.datetime(1960, 1, 11, 0, 0),
#  datetime.datetime(1960, 1, 18, 0, 0),
#  datetime.datetime(1960, 1, 25, 0, 0),
#  datetime.datetime(1960, 2, 1, 0, 0),
#  datetime.datetime(1960, 2, 8, 0, 0),
#  datetime.datetime(1960, 2, 15, 0, 0),
#  datetime.datetime(1960, 2, 22, 0, 0),
#  datetime.datetime(1960, 2, 29, 0, 0),
#  datetime.datetime(1960, 3, 7, 0, 0),
#  datetime.datetime(1960, 3, 14, 0, 0),
#  datetime.datetime(1960, 3, 21, 0, 0),
#  datetime.datetime(1960, 3, 28, 0, 0),
#  datetime.datetime(1960, 4, 4, 0, 0),
#  datetime.datetime(1960, 4, 11, 0, 0),
#  datetime.datetime(1960, 4, 18, 0, 0),
#  datetime.datetime(1960, 4, 25, 0, 0),
#  datetime.datetime(1960, 5, 2, 0, 0),
#  datetime.datetime(1960, 5, 9, 0, 0),
#  datetime.datetime(1960, 5, 16, 0, 0),
#  datetime.datetime(1960, 5, 23, 0, 0),
#  datetime.datetime(1960, 5, 30, 0, 0),
#  datetime.datetime(1960, 6, 6, 0, 0),
#  datetime.datetime(1960, 6, 13, 0, 0),
#  datetime.datetime(1960, 6, 20, 0, 0),
#  datetime.datetime(1960, 6, 27, 0, 0),
#  datetime.datetime(1960, 7, 4, 0, 0),
#  datetime.datetime(1960, 7, 11, 0, 0),
#  datetime.datetime(1960, 7, 18, 0, 0),
#  datetime.datetime(1960, 7, 25, 0, 0),
#  datetime.datetime(1960, 8, 1, 0, 0),
#  datetime.datetime(1960, 8, 8, 0, 0),
#  datetime.datetime(1960, 8, 15, 0, 0),
#  datetime.datetime(1960, 8, 22, 0, 0),
#  datetime.datetime(1960, 8, 29, 0, 0),
#  datetime.datetime(1960, 9, 5, 0, 0),
#  datetime.datetime(1960, 9, 12, 0, 0),
#  datetime.datetime(1960, 9, 19, 0, 0),
#  datetime.datetime(1960, 9, 26, 0, 0),
#  datetime.datetime(1960, 10, 3, 0, 0),
#  datetime.datetime(1960, 10, 10, 0, 0),
#  datetime.datetime(1960, 10, 17, 0, 0),
#  datetime.datetime(1960, 10, 24, 0, 0),
#  datetime.datetime(1960, 10, 31, 0, 0),
#  datetime.datetime(1960, 11, 7, 0, 0),
#  datetime.datetime(1960, 11, 14, 0, 0),
#  datetime.datetime(1960, 11, 21, 0, 0),
#  datetime.datetime(1960, 11, 28, 0, 0),
#  datetime.datetime(1960, 12, 5, 0, 0),
#  datetime.datetime(1960, 12, 12, 0, 0),
#  datetime.datetime(1960, 12, 19, 0, 0),
#  datetime.datetime(1960, 12, 26, 0, 0),
#  datetime.datetime(1961, 1, 2, 0, 0),
#  datetime.datetime(1961, 1, 9, 0, 0),
#  datetime.datetime(1961, 1, 16, 0, 0),
#  datetime.datetime(1961, 1, 23, 0, 0),
#  datetime.datetime(1961, 1, 30, 0, 0),
#  datetime.datetime(1961, 2, 6, 0, 0),
#  datetime.datetime(1961, 2, 13, 0, 0),
#  datetime.datetime(1961, 2, 20, 0, 0),
#  datetime.datetime(1961, 2, 27, 0, 0),
#  datetime.datetime(1961, 3, 6, 0, 0),
#  datetime.datetime(1961, 3, 13, 0, 0),
#  datetime.datetime(1961, 3, 20, 0, 0),
#  datetime.datetime(1961, 3, 27, 0, 0),
#  datetime.datetime(1961, 4, 3, 0, 0),
#  datetime.datetime(1961, 4, 10, 0, 0),
#  datetime.datetime(1961, 4, 17, 0, 0),
#  datetime.datetime(1961, 4, 24, 0, 0),
#  datetime.datetime(1961, 5, 1, 0, 0),
#  datetime.datetime(1961, 5, 8, 0, 0),
#  datetime.datetime(1961, 5, 15, 0, 0),
#  datetime.datetime(1961, 5, 22, 0, 0),
#  datetime.datetime(1961, 5, 29, 0, 0),
#  datetime.datetime(1961, 6, 5, 0, 0),
#  datetime.datetime(1961, 6, 12, 0, 0),
#  datetime.datetime(1961, 6, 19, 0, 0),
#  datetime.datetime(1961, 6, 26, 0, 0),
#  datetime.datetime(1961, 7, 3, 0, 0),
#  datetime.datetime(1961, 7, 10, 0, 0),
#  datetime.datetime(1961, 7, 17, 0, 0),
#  datetime.datetime(1961, 7, 24, 0, 0),
#  datetime.datetime(1961, 7, 31, 0, 0),
#  datetime.datetime(1961, 8, 7, 0, 0),
#  datetime.datetime(1961, 8, 14, 0, 0),
#  datetime.datetime(1961, 8, 21, 0, 0),
#  datetime.datetime(1961, 8, 28, 0, 0),
#  datetime.datetime(1961, 9, 4, 0, 0),
#  datetime.datetime(1961, 9, 11, 0, 0),
#  datetime.datetime(1961, 9, 18, 0, 0),
#  datetime.datetime(1961, 9, 25, 0, 0),
#  datetime.datetime(1961, 10, 2, 0, 0),
#  datetime.datetime(1961, 10, 9, 0, 0),
#  datetime.datetime(1961, 10, 16, 0, 0),
#  datetime.datetime(1961, 10, 23, 0, 0),
#  datetime.datetime(1961, 10, 30, 0, 0),
#  datetime.datetime(1961, 11, 6, 0, 0),
#  datetime.datetime(1961, 11, 13, 0, 0),
#  datetime.datetime(1961, 11, 20, 0, 0),
#  datetime.datetime(1961, 11, 27, 0, 0),
#  datetime.datetime(1961, 12, 4, 0, 0),
#  datetime.datetime(1961, 12, 11, 0, 0),
#  datetime.datetime(1961, 12, 18, 0, 0),
#  datetime.datetime(1961, 12, 25, 0, 0),
#  datetime.datetime(1962, 1, 1, 0, 0),
#  datetime.datetime(1962, 1, 8, 0, 0),
#  datetime.datetime(1962, 1, 15, 0, 0),
#  datetime.datetime(1962, 1, 22, 0, 0),
#  datetime.datetime(1962, 1, 29, 0, 0),
#  datetime.datetime(1962, 2, 5, 0, 0),
#  datetime.datetime(1962, 2, 12, 0, 0),
#  datetime.datetime(1962, 2, 19, 0, 0),
#  datetime.datetime(1962, 2, 26, 0, 0),
#  datetime.datetime(1962, 3, 5, 0, 0),
#  datetime.datetime(1962, 3, 12, 0, 0),
#  datetime.datetime(1962, 3, 19, 0, 0),
#  datetime.datetime(1962, 3, 26, 0, 0),
#  datetime.datetime(1962, 4, 2, 0, 0),
#  datetime.datetime(1962, 4, 9, 0, 0),
#  datetime.datetime(1962, 4, 16, 0, 0),
#  datetime.datetime(1962, 4, 23, 0, 0),
#  datetime.datetime(1962, 4, 30, 0, 0),
#  datetime.datetime(1962, 5, 7, 0, 0),
#  datetime.datetime(1962, 5, 14, 0, 0),
#  datetime.datetime(1962, 5, 21, 0, 0),
#  datetime.datetime(1962, 5, 28, 0, 0),
#  datetime.datetime(1962, 6, 4, 0, 0),
#  datetime.datetime(1962, 6, 11, 0, 0),
#  datetime.datetime(1962, 6, 18, 0, 0),
#  datetime.datetime(1962, 6, 25, 0, 0),
#  datetime.datetime(1962, 7, 2, 0, 0),
#  datetime.datetime(1962, 7, 9, 0, 0),
#  datetime.datetime(1962, 7, 16, 0, 0),
#  datetime.datetime(1962, 7, 23, 0, 0),
#  datetime.datetime(1962, 7, 30, 0, 0),
#  datetime.datetime(1962, 8, 6, 0, 0),
#  datetime.datetime(1962, 8, 13, 0, 0),
#  datetime.datetime(1962, 8, 20, 0, 0),
#  datetime.datetime(1962, 8, 27, 0, 0),
#  datetime.datetime(1962, 9, 3, 0, 0),
#  datetime.datetime(1962, 9, 10, 0, 0),
#  datetime.datetime(1962, 9, 17, 0, 0),
#  datetime.datetime(1962, 9, 24, 0, 0),
#  datetime.datetime(1962, 10, 1, 0, 0),
#  datetime.datetime(1962, 10, 8, 0, 0),
#  datetime.datetime(1962, 10, 15, 0, 0),
#  datetime.datetime(1962, 10, 22, 0, 0),
#  datetime.datetime(1962, 10, 29, 0, 0),
#  datetime.datetime(1962, 11, 5, 0, 0),
#  datetime.datetime(1962, 11, 12, 0, 0),
#  datetime.datetime(1962, 11, 19, 0, 0),
#  datetime.datetime(1962, 11, 26, 0, 0),
#  datetime.datetime(1962, 12, 3, 0, 0),
#  datetime.datetime(1962, 12, 10, 0, 0),
#  datetime.datetime(1962, 12, 17, 0, 0),
#  datetime.datetime(1962, 12, 24, 0, 0),
#  datetime.datetime(1962, 12, 31, 0, 0),
#  datetime.datetime(1963, 1, 7, 0, 0),
#  datetime.datetime(1963, 1, 14, 0, 0),
#  datetime.datetime(1963, 1, 21, 0, 0),
#  datetime.datetime(1963, 1, 28, 0, 0),
#  datetime.datetime(1963, 2, 4, 0, 0),
#  datetime.datetime(1963, 2, 11, 0, 0),
#  datetime.datetime(1963, 2, 18, 0, 0),
#  datetime.datetime(1963, 2, 25, 0, 0),
#  datetime.datetime(1963, 3, 4, 0, 0),
#  datetime.datetime(1963, 3, 11, 0, 0),
#  datetime.datetime(1963, 3, 18, 0, 0),
#  datetime.datetime(1963, 3, 25, 0, 0),
#  datetime.datetime(1963, 4, 1, 0, 0),
#  datetime.datetime(1963, 4, 8, 0, 0),
#  datetime.datetime(1963, 4, 15, 0, 0),
#  datetime.datetime(1963, 4, 22, 0, 0),
#  datetime.datetime(1963, 4, 29, 0, 0),
#  datetime.datetime(1963, 5, 6, 0, 0),
#  datetime.datetime(1963, 5, 13, 0, 0),
#  datetime.datetime(1963, 5, 20, 0, 0),
#  datetime.datetime(1963, 5, 27, 0, 0),
#  datetime.datetime(1963, 6, 3, 0, 0),
#  datetime.datetime(1963, 6, 10, 0, 0),
#  datetime.datetime(1963, 6, 17, 0, 0),
#  datetime.datetime(1963, 6, 24, 0, 0),
#  datetime.datetime(1963, 7, 1, 0, 0),
#  datetime.datetime(1963, 7, 8, 0, 0),
#  datetime.datetime(1963, 7, 15, 0, 0),
#  datetime.datetime(1963, 7, 22, 0, 0),
#  datetime.datetime(1963, 7, 29, 0, 0),
#  datetime.datetime(1963, 8, 5, 0, 0),
#  datetime.datetime(1963, 8, 12, 0, 0),
#  datetime.datetime(1963, 8, 19, 0, 0),
#  datetime.datetime(1963, 8, 26, 0, 0),
#  datetime.datetime(1963, 9, 2, 0, 0),
#  datetime.datetime(1963, 9, 9, 0, 0),
#  datetime.datetime(1963, 9, 16, 0, 0),
#  datetime.datetime(1963, 9, 23, 0, 0),
#  datetime.datetime(1963, 9, 30, 0, 0),
#  datetime.datetime(1963, 10, 7, 0, 0),
#  datetime.datetime(1963, 10, 14, 0, 0),
#  datetime.datetime(1963, 10, 21, 0, 0),
#  datetime.datetime(1963, 10, 28, 0, 0),
#  datetime.datetime(1963, 11, 4, 0, 0),
#  datetime.datetime(1963, 11, 11, 0, 0),
#  datetime.datetime(1963, 11, 18, 0, 0),
#  datetime.datetime(1963, 11, 25, 0, 0),
#  datetime.datetime(1963, 12, 2, 0, 0),
#  datetime.datetime(1963, 12, 9, 0, 0),
#  datetime.datetime(1963, 12, 16, 0, 0),
#  datetime.datetime(1963, 12, 23, 0, 0),
#  datetime.datetime(1963, 12, 30, 0, 0),
#  datetime.datetime(1964, 1, 6, 0, 0),
#  datetime.datetime(1964, 1, 13, 0, 0),
#  datetime.datetime(1964, 1, 20, 0, 0),
#  datetime.datetime(1964, 1, 27, 0, 0),
#  datetime.datetime(1964, 2, 3, 0, 0),
#  datetime.datetime(1964, 2, 10, 0, 0),
#  datetime.datetime(1964, 2, 17, 0, 0),
#  datetime.datetime(1964, 2, 24, 0, 0),
#  datetime.datetime(1964, 3, 2, 0, 0),
#  datetime.datetime(1964, 3, 9, 0, 0),
#  datetime.datetime(1964, 3, 16, 0, 0),
#  datetime.datetime(1964, 3, 23, 0, 0),
#  datetime.datetime(1964, 3, 30, 0, 0),
#  datetime.datetime(1964, 4, 6, 0, 0),
#  datetime.datetime(1964, 4, 13, 0, 0),
#  datetime.datetime(1964, 4, 20, 0, 0),
#  datetime.datetime(1964, 4, 27, 0, 0),
#  datetime.datetime(1964, 5, 4, 0, 0),
#  datetime.datetime(1964, 5, 11, 0, 0),
#  datetime.datetime(1964, 5, 18, 0, 0),
#  datetime.datetime(1964, 5, 25, 0, 0),
#  datetime.datetime(1964, 6, 1, 0, 0),
#  datetime.datetime(1964, 6, 8, 0, 0),
#  datetime.datetime(1964, 6, 15, 0, 0),
#  datetime.datetime(1964, 6, 22, 0, 0),
#  datetime.datetime(1964, 6, 29, 0, 0),
#  datetime.datetime(1964, 7, 6, 0, 0),
#  datetime.datetime(1964, 7, 13, 0, 0),
#  datetime.datetime(1964, 7, 20, 0, 0),
#  datetime.datetime(1964, 7, 27, 0, 0),
#  datetime.datetime(1964, 8, 3, 0, 0),
#  datetime.datetime(1964, 8, 10, 0, 0),
#  datetime.datetime(1964, 8, 17, 0, 0),
#  datetime.datetime(1964, 8, 24, 0, 0),
#  datetime.datetime(1964, 8, 31, 0, 0),
#  datetime.datetime(1964, 9, 7, 0, 0),
#  datetime.datetime(1964, 9, 14, 0, 0),
#  datetime.datetime(1964, 9, 21, 0, 0),
#  datetime.datetime(1964, 9, 28, 0, 0),
#  datetime.datetime(1964, 10, 5, 0, 0),
#  datetime.datetime(1964, 10, 12, 0, 0),
#  datetime.datetime(1964, 10, 19, 0, 0),
#  datetime.datetime(1964, 10, 26, 0, 0),
#  datetime.datetime(1964, 11, 2, 0, 0),
#  datetime.datetime(1964, 11, 9, 0, 0),
#  datetime.datetime(1964, 11, 16, 0, 0),
#  datetime.datetime(1964, 11, 23, 0, 0),
#  datetime.datetime(1964, 11, 30, 0, 0),
#  datetime.datetime(1964, 12, 7, 0, 0),
#  datetime.datetime(1964, 12, 14, 0, 0),
#  datetime.datetime(1964, 12, 21, 0, 0),
#  datetime.datetime(1964, 12, 28, 0, 0),
#  datetime.datetime(1965, 1, 4, 0, 0),
#  datetime.datetime(1965, 1, 11, 0, 0),
#  datetime.datetime(1965, 1, 18, 0, 0),
#  datetime.datetime(1965, 1, 25, 0, 0),
#  datetime.datetime(1965, 2, 1, 0, 0),
#  datetime.datetime(1965, 2, 8, 0, 0),
#  datetime.datetime(1965, 2, 15, 0, 0),
#  datetime.datetime(1965, 2, 22, 0, 0),
#  datetime.datetime(1965, 3, 1, 0, 0),
#  datetime.datetime(1965, 3, 8, 0, 0),
#  datetime.datetime(1965, 3, 15, 0, 0),
#  datetime.datetime(1965, 3, 22, 0, 0),
#  datetime.datetime(1965, 3, 29, 0, 0),
#  datetime.datetime(1965, 4, 5, 0, 0),
#  datetime.datetime(1965, 4, 12, 0, 0),
#  datetime.datetime(1965, 4, 19, 0, 0),
#  datetime.datetime(1965, 4, 26, 0, 0),
#  datetime.datetime(1965, 5, 3, 0, 0),
#  datetime.datetime(1965, 5, 10, 0, 0),
#  datetime.datetime(1965, 5, 17, 0, 0),
#  datetime.datetime(1965, 5, 24, 0, 0),
#  datetime.datetime(1965, 5, 31, 0, 0),
#  datetime.datetime(1965, 6, 7, 0, 0),
#  datetime.datetime(1965, 6, 14, 0, 0),
#  datetime.datetime(1965, 6, 21, 0, 0),
#  datetime.datetime(1965, 6, 28, 0, 0),
#  datetime.datetime(1965, 7, 5, 0, 0),
#  datetime.datetime(1965, 7, 12, 0, 0),
#  datetime.datetime(1965, 7, 19, 0, 0),
#  datetime.datetime(1965, 7, 26, 0, 0),
#  datetime.datetime(1965, 8, 2, 0, 0),
#  datetime.datetime(1965, 8, 9, 0, 0),
#  datetime.datetime(1965, 8, 16, 0, 0),
#  datetime.datetime(1965, 8, 23, 0, 0),
#  datetime.datetime(1965, 8, 30, 0, 0),
#  datetime.datetime(1965, 9, 6, 0, 0),
#  datetime.datetime(1965, 9, 13, 0, 0),
#  datetime.datetime(1965, 9, 20, 0, 0),
#  datetime.datetime(1965, 9, 27, 0, 0),
#  datetime.datetime(1965, 10, 4, 0, 0),
#  datetime.datetime(1965, 10, 11, 0, 0),
#  datetime.datetime(1965, 10, 18, 0, 0),
#  datetime.datetime(1965, 10, 25, 0, 0),
#  datetime.datetime(1965, 11, 1, 0, 0),
#  datetime.datetime(1965, 11, 8, 0, 0),
#  datetime.datetime(1965, 11, 15, 0, 0),
#  datetime.datetime(1965, 11, 22, 0, 0),
#  datetime.datetime(1965, 11, 29, 0, 0),
#  datetime.datetime(1965, 12, 6, 0, 0),
#  datetime.datetime(1965, 12, 13, 0, 0),
#  datetime.datetime(1965, 12, 20, 0, 0),
#  datetime.datetime(1965, 12, 27, 0, 0),
#  datetime.datetime(1966, 1, 3, 0, 0),
#  datetime.datetime(1966, 1, 10, 0, 0),
#  datetime.datetime(1966, 1, 17, 0, 0),
#  datetime.datetime(1966, 1, 24, 0, 0),
#  datetime.datetime(1966, 1, 31, 0, 0),
#  datetime.datetime(1966, 2, 7, 0, 0),
#  datetime.datetime(1966, 2, 14, 0, 0),
#  datetime.datetime(1966, 2, 21, 0, 0),
#  datetime.datetime(1966, 2, 28, 0, 0),
#  datetime.datetime(1966, 3, 7, 0, 0),
#  datetime.datetime(1966, 3, 14, 0, 0),
#  datetime.datetime(1966, 3, 21, 0, 0),
#  datetime.datetime(1966, 3, 28, 0, 0),
#  datetime.datetime(1966, 4, 4, 0, 0),
#  datetime.datetime(1966, 4, 11, 0, 0),
#  datetime.datetime(1966, 4, 18, 0, 0),
#  datetime.datetime(1966, 4, 25, 0, 0),
#  datetime.datetime(1966, 5, 2, 0, 0),
#  datetime.datetime(1966, 5, 9, 0, 0),
#  datetime.datetime(1966, 5, 16, 0, 0),
#  datetime.datetime(1966, 5, 23, 0, 0),
#  datetime.datetime(1966, 5, 30, 0, 0),
#  datetime.datetime(1966, 6, 6, 0, 0),
#  datetime.datetime(1966, 6, 13, 0, 0),
#  datetime.datetime(1966, 6, 20, 0, 0),
#  datetime.datetime(1966, 6, 27, 0, 0),
#  datetime.datetime(1966, 7, 4, 0, 0),
#  datetime.datetime(1966, 7, 11, 0, 0),
#  datetime.datetime(1966, 7, 18, 0, 0),
#  datetime.datetime(1966, 7, 25, 0, 0),
#  datetime.datetime(1966, 8, 1, 0, 0),
#  datetime.datetime(1966, 8, 8, 0, 0),
#  datetime.datetime(1966, 8, 15, 0, 0),
#  datetime.datetime(1966, 8, 22, 0, 0),
#  datetime.datetime(1966, 8, 29, 0, 0),
#  datetime.datetime(1966, 9, 5, 0, 0),
#  datetime.datetime(1966, 9, 12, 0, 0),
#  datetime.datetime(1966, 9, 19, 0, 0),
#  datetime.datetime(1966, 9, 26, 0, 0),
#  datetime.datetime(1966, 10, 3, 0, 0),
#  datetime.datetime(1966, 10, 10, 0, 0),
#  datetime.datetime(1966, 10, 17, 0, 0),
#  datetime.datetime(1966, 10, 24, 0, 0),
#  datetime.datetime(1966, 10, 31, 0, 0),
#  datetime.datetime(1966, 11, 7, 0, 0),
#  datetime.datetime(1966, 11, 14, 0, 0),
#  datetime.datetime(1966, 11, 21, 0, 0),
#  datetime.datetime(1966, 11, 28, 0, 0),
#  datetime.datetime(1966, 12, 5, 0, 0),
#  datetime.datetime(1966, 12, 12, 0, 0),
#  datetime.datetime(1966, 12, 19, 0, 0),
#  datetime.datetime(1966, 12, 26, 0, 0),
#  datetime.datetime(1967, 1, 2, 0, 0),
#  datetime.datetime(1967, 1, 9, 0, 0),
#  datetime.datetime(1967, 1, 16, 0, 0),
#  datetime.datetime(1967, 1, 23, 0, 0),
#  datetime.datetime(1967, 1, 30, 0, 0),
#  datetime.datetime(1967, 2, 6, 0, 0),
#  datetime.datetime(1967, 2, 13, 0, 0),
#  datetime.datetime(1967, 2, 20, 0, 0),
#  datetime.datetime(1967, 2, 27, 0, 0),
#  datetime.datetime(1967, 3, 6, 0, 0),
#  datetime.datetime(1967, 3, 13, 0, 0),
#  datetime.datetime(1967, 3, 20, 0, 0),
#  datetime.datetime(1967, 3, 27, 0, 0),
#  datetime.datetime(1967, 4, 3, 0, 0),
#  datetime.datetime(1967, 4, 10, 0, 0),
#  datetime.datetime(1967, 4, 17, 0, 0),
#  datetime.datetime(1967, 4, 24, 0, 0),
#  datetime.datetime(1967, 5, 1, 0, 0),
#  datetime.datetime(1967, 5, 8, 0, 0),
#  datetime.datetime(1967, 5, 15, 0, 0),
#  datetime.datetime(1967, 5, 22, 0, 0),
#  datetime.datetime(1967, 5, 29, 0, 0),
#  datetime.datetime(1967, 6, 5, 0, 0),
#  datetime.datetime(1967, 6, 12, 0, 0),
#  datetime.datetime(1967, 6, 19, 0, 0),
#  datetime.datetime(1967, 6, 26, 0, 0),
#  datetime.datetime(1967, 7, 3, 0, 0),
#  datetime.datetime(1967, 7, 10, 0, 0),
#  datetime.datetime(1967, 7, 17, 0, 0),
#  datetime.datetime(1967, 7, 24, 0, 0),
#  datetime.datetime(1967, 7, 31, 0, 0),
#  datetime.datetime(1967, 8, 7, 0, 0),
#  datetime.datetime(1967, 8, 14, 0, 0),
#  datetime.datetime(1967, 8, 21, 0, 0),
#  datetime.datetime(1967, 8, 28, 0, 0),
#  datetime.datetime(1967, 9, 4, 0, 0),
#  datetime.datetime(1967, 9, 11, 0, 0),
#  datetime.datetime(1967, 9, 18, 0, 0),
#  datetime.datetime(1967, 9, 25, 0, 0),
#  datetime.datetime(1967, 10, 2, 0, 0),
#  datetime.datetime(1967, 10, 9, 0, 0),
#  datetime.datetime(1967, 10, 16, 0, 0),
#  datetime.datetime(1967, 10, 23, 0, 0),
#  datetime.datetime(1967, 10, 30, 0, 0),
#  datetime.datetime(1967, 11, 6, 0, 0),
#  datetime.datetime(1967, 11, 13, 0, 0),
#  datetime.datetime(1967, 11, 20, 0, 0),
#  datetime.datetime(1967, 11, 27, 0, 0),
#  datetime.datetime(1967, 12, 4, 0, 0),
#  datetime.datetime(1967, 12, 11, 0, 0),
#  datetime.datetime(1967, 12, 18, 0, 0),
#  datetime.datetime(1967, 12, 25, 0, 0),
#  datetime.datetime(1968, 1, 1, 0, 0),
#  datetime.datetime(1968, 1, 8, 0, 0),
#  datetime.datetime(1968, 1, 15, 0, 0),
#  datetime.datetime(1968, 1, 22, 0, 0),
#  datetime.datetime(1968, 1, 29, 0, 0),
#  datetime.datetime(1968, 2, 5, 0, 0),
#  datetime.datetime(1968, 2, 12, 0, 0),
#  datetime.datetime(1968, 2, 19, 0, 0),
#  datetime.datetime(1968, 2, 26, 0, 0),
#  datetime.datetime(1968, 3, 4, 0, 0),
#  datetime.datetime(1968, 3, 11, 0, 0),
#  datetime.datetime(1968, 3, 18, 0, 0),
#  datetime.datetime(1968, 3, 25, 0, 0),
#  datetime.datetime(1968, 4, 1, 0, 0),
#  datetime.datetime(1968, 4, 8, 0, 0),
#  datetime.datetime(1968, 4, 15, 0, 0),
#  datetime.datetime(1968, 4, 22, 0, 0),
#  datetime.datetime(1968, 4, 29, 0, 0),
#  datetime.datetime(1968, 5, 6, 0, 0),
#  datetime.datetime(1968, 5, 13, 0, 0),
#  datetime.datetime(1968, 5, 20, 0, 0),
#  datetime.datetime(1968, 5, 27, 0, 0),
#  datetime.datetime(1968, 6, 3, 0, 0),
#  datetime.datetime(1968, 6, 10, 0, 0),
#  datetime.datetime(1968, 6, 17, 0, 0),
#  datetime.datetime(1968, 6, 24, 0, 0),
#  datetime.datetime(1968, 7, 1, 0, 0),
#  datetime.datetime(1968, 7, 8, 0, 0),
#  datetime.datetime(1968, 7, 15, 0, 0),
#  datetime.datetime(1968, 7, 22, 0, 0),
#  datetime.datetime(1968, 7, 29, 0, 0),
#  datetime.datetime(1968, 8, 5, 0, 0),
#  datetime.datetime(1968, 8, 12, 0, 0),
#  datetime.datetime(1968, 8, 19, 0, 0),
#  datetime.datetime(1968, 8, 26, 0, 0),
#  datetime.datetime(1968, 9, 2, 0, 0),
#  datetime.datetime(1968, 9, 9, 0, 0),
#  datetime.datetime(1968, 9, 16, 0, 0),
#  datetime.datetime(1968, 9, 23, 0, 0),
#  datetime.datetime(1968, 9, 30, 0, 0),
#  datetime.datetime(1968, 10, 7, 0, 0),
#  datetime.datetime(1968, 10, 14, 0, 0),
#  datetime.datetime(1968, 10, 21, 0, 0),
#  datetime.datetime(1968, 10, 28, 0, 0),
#  datetime.datetime(1968, 11, 4, 0, 0),
#  datetime.datetime(1968, 11, 11, 0, 0),
#  datetime.datetime(1968, 11, 18, 0, 0),
#  datetime.datetime(1968, 11, 25, 0, 0),
#  datetime.datetime(1968, 12, 2, 0, 0),
#  datetime.datetime(1968, 12, 9, 0, 0),
#  datetime.datetime(1968, 12, 16, 0, 0),
#  datetime.datetime(1968, 12, 23, 0, 0),
#  datetime.datetime(1968, 12, 30, 0, 0),
#  datetime.datetime(1969, 1, 6, 0, 0),
#  datetime.datetime(1969, 1, 13, 0, 0),
#  datetime.datetime(1969, 1, 20, 0, 0),
#  datetime.datetime(1969, 1, 27, 0, 0),
#  datetime.datetime(1969, 2, 3, 0, 0),
#  datetime.datetime(1969, 2, 10, 0, 0),
#  datetime.datetime(1969, 2, 17, 0, 0),
#  datetime.datetime(1969, 2, 24, 0, 0),
#  datetime.datetime(1969, 3, 3, 0, 0),
#  datetime.datetime(1969, 3, 10, 0, 0),
#  datetime.datetime(1969, 3, 17, 0, 0),
#  datetime.datetime(1969, 3, 24, 0, 0),
#  datetime.datetime(1969, 3, 31, 0, 0),
#  datetime.datetime(1969, 4, 7, 0, 0),
#  datetime.datetime(1969, 4, 14, 0, 0),
#  datetime.datetime(1969, 4, 21, 0, 0),
#  datetime.datetime(1969, 4, 28, 0, 0),
#  datetime.datetime(1969, 5, 5, 0, 0),
#  datetime.datetime(1969, 5, 12, 0, 0),
#  datetime.datetime(1969, 5, 19, 0, 0),
#  datetime.datetime(1969, 5, 26, 0, 0),
#  datetime.datetime(1969, 6, 2, 0, 0),
#  datetime.datetime(1969, 6, 9, 0, 0),
#  datetime.datetime(1969, 6, 16, 0, 0),
#  datetime.datetime(1969, 6, 23, 0, 0),
#  datetime.datetime(1969, 6, 30, 0, 0),
#  datetime.datetime(1969, 7, 7, 0, 0),
#  datetime.datetime(1969, 7, 14, 0, 0),
#  datetime.datetime(1969, 7, 21, 0, 0),
#  datetime.datetime(1969, 7, 28, 0, 0),
#  datetime.datetime(1969, 8, 4, 0, 0),
#  datetime.datetime(1969, 8, 11, 0, 0),
#  datetime.datetime(1969, 8, 18, 0, 0),
#  datetime.datetime(1969, 8, 25, 0, 0),
#  datetime.datetime(1969, 9, 1, 0, 0),
#  datetime.datetime(1969, 9, 8, 0, 0),
#  datetime.datetime(1969, 9, 15, 0, 0),
#  datetime.datetime(1969, 9, 22, 0, 0),
#  datetime.datetime(1969, 9, 29, 0, 0),
#  datetime.datetime(1969, 10, 6, 0, 0),
#  datetime.datetime(1969, 10, 13, 0, 0),
#  datetime.datetime(1969, 10, 20, 0, 0),
#  datetime.datetime(1969, 10, 27, 0, 0),
#  datetime.datetime(1969, 11, 3, 0, 0),
#  datetime.datetime(1969, 11, 10, 0, 0),
#  datetime.datetime(1969, 11, 17, 0, 0),
#  datetime.datetime(1969, 11, 24, 0, 0),
#  datetime.datetime(1969, 12, 1, 0, 0),
#  datetime.datetime(1969, 12, 8, 0, 0),
#  datetime.datetime(1969, 12, 15, 0, 0),
#  datetime.datetime(1969, 12, 22, 0, 0),
#  datetime.datetime(1969, 12, 29, 0, 0),
#  datetime.datetime(1970, 1, 5, 0, 0),
#  datetime.datetime(1970, 1, 12, 0, 0),
#  datetime.datetime(1970, 1, 19, 0, 0),
#  datetime.datetime(1970, 1, 26, 0, 0),
#  datetime.datetime(1970, 2, 2, 0, 0),
#  datetime.datetime(1970, 2, 9, 0, 0),
#  datetime.datetime(1970, 2, 16, 0, 0),
#  datetime.datetime(1970, 2, 23, 0, 0),
#  datetime.datetime(1970, 3, 2, 0, 0),
#  datetime.datetime(1970, 3, 9, 0, 0),
#  datetime.datetime(1970, 3, 16, 0, 0),
#  datetime.datetime(1970, 3, 23, 0, 0),
#  datetime.datetime(1970, 3, 30, 0, 0),
#  datetime.datetime(1970, 4, 6, 0, 0),
#  datetime.datetime(1970, 4, 13, 0, 0),
#  datetime.datetime(1970, 4, 20, 0, 0),
#  datetime.datetime(1970, 4, 27, 0, 0),
#  datetime.datetime(1970, 5, 4, 0, 0),
#  datetime.datetime(1970, 5, 11, 0, 0),
#  datetime.datetime(1970, 5, 18, 0, 0),
#  datetime.datetime(1970, 5, 25, 0, 0),
#  datetime.datetime(1970, 6, 1, 0, 0),
#  datetime.datetime(1970, 6, 8, 0, 0),
#  datetime.datetime(1970, 6, 15, 0, 0),
#  datetime.datetime(1970, 6, 22, 0, 0),
#  datetime.datetime(1970, 6, 29, 0, 0),
#  datetime.datetime(1970, 7, 6, 0, 0),
#  datetime.datetime(1970, 7, 13, 0, 0),
#  datetime.datetime(1970, 7, 20, 0, 0),
#  datetime.datetime(1970, 7, 27, 0, 0),
#  datetime.datetime(1970, 8, 3, 0, 0),
#  datetime.datetime(1970, 8, 10, 0, 0),
#  datetime.datetime(1970, 8, 17, 0, 0),
#  datetime.datetime(1970, 8, 24, 0, 0),
#  datetime.datetime(1970, 8, 31, 0, 0),
#  datetime.datetime(1970, 9, 7, 0, 0),
#  datetime.datetime(1970, 9, 14, 0, 0),
#  datetime.datetime(1970, 9, 21, 0, 0),
#  datetime.datetime(1970, 9, 28, 0, 0),
#  datetime.datetime(1970, 10, 5, 0, 0),
#  datetime.datetime(1970, 10, 12, 0, 0),
#  datetime.datetime(1970, 10, 19, 0, 0),
#  datetime.datetime(1970, 10, 26, 0, 0),
#  datetime.datetime(1970, 11, 2, 0, 0),
#  datetime.datetime(1970, 11, 9, 0, 0),
#  datetime.datetime(1970, 11, 16, 0, 0),
#  datetime.datetime(1970, 11, 23, 0, 0),
#  datetime.datetime(1970, 11, 30, 0, 0),
#  datetime.datetime(1970, 12, 7, 0, 0),
#  datetime.datetime(1970, 12, 14, 0, 0),
#  datetime.datetime(1970, 12, 21, 0, 0),
#  datetime.datetime(1970, 12, 28, 0, 0),
#  datetime.datetime(1971, 1, 4, 0, 0),
#  datetime.datetime(1971, 1, 11, 0, 0),
#  datetime.datetime(1971, 1, 18, 0, 0),
#  datetime.datetime(1971, 1, 25, 0, 0),
#  datetime.datetime(1971, 2, 1, 0, 0),
#  datetime.datetime(1971, 2, 8, 0, 0),
#  datetime.datetime(1971, 2, 15, 0, 0),
#  datetime.datetime(1971, 2, 22, 0, 0),
#  datetime.datetime(1971, 3, 1, 0, 0),
#  datetime.datetime(1971, 3, 8, 0, 0),
#  datetime.datetime(1971, 3, 15, 0, 0),
#  datetime.datetime(1971, 3, 22, 0, 0),
#  datetime.datetime(1971, 3, 29, 0, 0),
#  datetime.datetime(1971, 4, 5, 0, 0),
#  datetime.datetime(1971, 4, 12, 0, 0),
#  datetime.datetime(1971, 4, 19, 0, 0),
#  datetime.datetime(1971, 4, 26, 0, 0),
#  datetime.datetime(1971, 5, 3, 0, 0),
#  datetime.datetime(1971, 5, 10, 0, 0),
#  datetime.datetime(1971, 5, 17, 0, 0),
#  datetime.datetime(1971, 5, 24, 0, 0),
#  datetime.datetime(1971, 5, 31, 0, 0),
#  datetime.datetime(1971, 6, 7, 0, 0),
#  datetime.datetime(1971, 6, 14, 0, 0),
#  datetime.datetime(1971, 6, 21, 0, 0),
#  datetime.datetime(1971, 6, 28, 0, 0),
#  datetime.datetime(1971, 7, 5, 0, 0),
#  datetime.datetime(1971, 7, 12, 0, 0),
#  datetime.datetime(1971, 7, 19, 0, 0),
#  datetime.datetime(1971, 7, 26, 0, 0),
#  datetime.datetime(1971, 8, 2, 0, 0),
#  datetime.datetime(1971, 8, 9, 0, 0),
#  datetime.datetime(1971, 8, 16, 0, 0),
#  datetime.datetime(1971, 8, 23, 0, 0),
#  datetime.datetime(1971, 8, 30, 0, 0),
#  datetime.datetime(1971, 9, 6, 0, 0),
#  datetime.datetime(1971, 9, 13, 0, 0),
#  datetime.datetime(1971, 9, 20, 0, 0),
#  datetime.datetime(1971, 9, 27, 0, 0),
#  datetime.datetime(1971, 10, 4, 0, 0),
#  datetime.datetime(1971, 10, 11, 0, 0),
#  datetime.datetime(1971, 10, 18, 0, 0),
#  datetime.datetime(1971, 10, 25, 0, 0),
#  datetime.datetime(1971, 11, 1, 0, 0),
#  datetime.datetime(1971, 11, 8, 0, 0),
#  datetime.datetime(1971, 11, 15, 0, 0),
#  datetime.datetime(1971, 11, 22, 0, 0),
#  datetime.datetime(1971, 11, 29, 0, 0),
#  datetime.datetime(1971, 12, 6, 0, 0),
#  datetime.datetime(1971, 12, 13, 0, 0),
#  datetime.datetime(1971, 12, 20, 0, 0),
#  datetime.datetime(1971, 12, 27, 0, 0),
#  datetime.datetime(1972, 1, 3, 0, 0),
#  datetime.datetime(1972, 1, 10, 0, 0),
#  datetime.datetime(1972, 1, 17, 0, 0),
#  datetime.datetime(1972, 1, 24, 0, 0),
#  datetime.datetime(1972, 1, 31, 0, 0),
#  datetime.datetime(1972, 2, 7, 0, 0),
#  datetime.datetime(1972, 2, 14, 0, 0),
#  datetime.datetime(1972, 2, 21, 0, 0),
#  datetime.datetime(1972, 2, 28, 0, 0),
#  datetime.datetime(1972, 3, 6, 0, 0),
#  datetime.datetime(1972, 3, 13, 0, 0),
#  datetime.datetime(1972, 3, 20, 0, 0),
#  datetime.datetime(1972, 3, 27, 0, 0),
#  datetime.datetime(1972, 4, 3, 0, 0),
#  datetime.datetime(1972, 4, 10, 0, 0),
#  datetime.datetime(1972, 4, 17, 0, 0),
#  datetime.datetime(1972, 4, 24, 0, 0),
#  datetime.datetime(1972, 5, 1, 0, 0),
#  datetime.datetime(1972, 5, 8, 0, 0),
#  datetime.datetime(1972, 5, 15, 0, 0),
#  datetime.datetime(1972, 5, 22, 0, 0),
#  datetime.datetime(1972, 5, 29, 0, 0),
#  datetime.datetime(1972, 6, 5, 0, 0),
#  datetime.datetime(1972, 6, 12, 0, 0),
#  datetime.datetime(1972, 6, 19, 0, 0),
#  datetime.datetime(1972, 6, 26, 0, 0),
#  datetime.datetime(1972, 7, 3, 0, 0),
#  datetime.datetime(1972, 7, 10, 0, 0),
#  datetime.datetime(1972, 7, 17, 0, 0),
#  datetime.datetime(1972, 7, 24, 0, 0),
#  datetime.datetime(1972, 7, 31, 0, 0),
#  datetime.datetime(1972, 8, 7, 0, 0),
#  datetime.datetime(1972, 8, 14, 0, 0),
#  datetime.datetime(1972, 8, 21, 0, 0),
#  datetime.datetime(1972, 8, 28, 0, 0),
#  datetime.datetime(1972, 9, 4, 0, 0),
#  datetime.datetime(1972, 9, 11, 0, 0),
#  datetime.datetime(1972, 9, 18, 0, 0),
#  datetime.datetime(1972, 9, 25, 0, 0),
#  datetime.datetime(1972, 10, 2, 0, 0),
#  datetime.datetime(1972, 10, 9, 0, 0),
#  datetime.datetime(1972, 10, 16, 0, 0),
#  datetime.datetime(1972, 10, 23, 0, 0),
#  datetime.datetime(1972, 10, 30, 0, 0),
#  datetime.datetime(1972, 11, 6, 0, 0),
#  datetime.datetime(1972, 11, 13, 0, 0),
#  datetime.datetime(1972, 11, 20, 0, 0),
#  datetime.datetime(1972, 11, 27, 0, 0),
#  datetime.datetime(1972, 12, 4, 0, 0),
#  datetime.datetime(1972, 12, 11, 0, 0),
#  datetime.datetime(1972, 12, 18, 0, 0),
#  datetime.datetime(1972, 12, 25, 0, 0),
#  datetime.datetime(1973, 1, 1, 0, 0),
#  datetime.datetime(1973, 1, 8, 0, 0),
#  datetime.datetime(1973, 1, 15, 0, 0),
#  datetime.datetime(1973, 1, 22, 0, 0),
#  datetime.datetime(1973, 1, 29, 0, 0),
#  datetime.datetime(1973, 2, 5, 0, 0),
#  datetime.datetime(1973, 2, 12, 0, 0),
#  datetime.datetime(1973, 2, 19, 0, 0),
#  datetime.datetime(1973, 2, 26, 0, 0),
#  datetime.datetime(1973, 3, 5, 0, 0),
#  datetime.datetime(1973, 3, 12, 0, 0),
#  datetime.datetime(1973, 3, 19, 0, 0),
#  datetime.datetime(1973, 3, 26, 0, 0),
#  datetime.datetime(1973, 4, 2, 0, 0),
#  datetime.datetime(1973, 4, 9, 0, 0),
#  datetime.datetime(1973, 4, 16, 0, 0),
#  datetime.datetime(1973, 4, 23, 0, 0),
#  datetime.datetime(1973, 4, 30, 0, 0),
#  datetime.datetime(1973, 5, 7, 0, 0),
#  datetime.datetime(1973, 5, 14, 0, 0),
#  datetime.datetime(1973, 5, 21, 0, 0),
#  datetime.datetime(1973, 5, 28, 0, 0),
#  datetime.datetime(1973, 6, 4, 0, 0),
#  datetime.datetime(1973, 6, 11, 0, 0),
#  datetime.datetime(1973, 6, 18, 0, 0),
#  datetime.datetime(1973, 6, 25, 0, 0),
#  datetime.datetime(1973, 7, 2, 0, 0),
#  datetime.datetime(1973, 7, 9, 0, 0),
#  datetime.datetime(1973, 7, 16, 0, 0),
#  datetime.datetime(1973, 7, 23, 0, 0),
#  datetime.datetime(1973, 7, 30, 0, 0),
#  datetime.datetime(1973, 8, 6, 0, 0),
#  datetime.datetime(1973, 8, 13, 0, 0),
#  datetime.datetime(1973, 8, 20, 0, 0),
#  datetime.datetime(1973, 8, 27, 0, 0),
#  datetime.datetime(1973, 9, 3, 0, 0),
#  datetime.datetime(1973, 9, 10, 0, 0),
#  datetime.datetime(1973, 9, 17, 0, 0),
#  datetime.datetime(1973, 9, 24, 0, 0),
#  datetime.datetime(1973, 10, 1, 0, 0),
#  datetime.datetime(1973, 10, 8, 0, 0),
#  datetime.datetime(1973, 10, 15, 0, 0),
#  datetime.datetime(1973, 10, 22, 0, 0),
#  datetime.datetime(1973, 10, 29, 0, 0),
#  datetime.datetime(1973, 11, 5, 0, 0),
#  datetime.datetime(1973, 11, 12, 0, 0),
#  datetime.datetime(1973, 11, 19, 0, 0),
#  datetime.datetime(1973, 11, 26, 0, 0),
#  datetime.datetime(1973, 12, 3, 0, 0),
#  datetime.datetime(1973, 12, 10, 0, 0),
#  datetime.datetime(1973, 12, 17, 0, 0),
#  datetime.datetime(1973, 12, 24, 0, 0),
#  datetime.datetime(1973, 12, 31, 0, 0),
#  datetime.datetime(1974, 1, 7, 0, 0),
#  datetime.datetime(1974, 1, 14, 0, 0),
#  datetime.datetime(1974, 1, 21, 0, 0),
#  datetime.datetime(1974, 1, 28, 0, 0),
#  datetime.datetime(1974, 2, 4, 0, 0),
#  datetime.datetime(1974, 2, 11, 0, 0),
#  datetime.datetime(1974, 2, 18, 0, 0),
#  datetime.datetime(1974, 2, 25, 0, 0),
#  datetime.datetime(1974, 3, 4, 0, 0),
#  datetime.datetime(1974, 3, 11, 0, 0),
#  datetime.datetime(1974, 3, 18, 0, 0),
#  datetime.datetime(1974, 3, 25, 0, 0),
#  datetime.datetime(1974, 4, 1, 0, 0),
#  datetime.datetime(1974, 4, 8, 0, 0),
#  datetime.datetime(1974, 4, 15, 0, 0),
#  datetime.datetime(1974, 4, 22, 0, 0),
#  datetime.datetime(1974, 4, 29, 0, 0),
#  datetime.datetime(1974, 5, 6, 0, 0),
#  datetime.datetime(1974, 5, 13, 0, 0),
#  datetime.datetime(1974, 5, 20, 0, 0),
#  datetime.datetime(1974, 5, 27, 0, 0),
#  datetime.datetime(1974, 6, 3, 0, 0),
#  datetime.datetime(1974, 6, 10, 0, 0),
#  datetime.datetime(1974, 6, 17, 0, 0),
#  datetime.datetime(1974, 6, 24, 0, 0),
#  datetime.datetime(1974, 7, 1, 0, 0),
#  datetime.datetime(1974, 7, 8, 0, 0),
#  datetime.datetime(1974, 7, 15, 0, 0),
#  datetime.datetime(1974, 7, 22, 0, 0),
#  datetime.datetime(1974, 7, 29, 0, 0),
#  datetime.datetime(1974, 8, 5, 0, 0),
#  datetime.datetime(1974, 8, 12, 0, 0),
#  datetime.datetime(1974, 8, 19, 0, 0),
#  datetime.datetime(1974, 8, 26, 0, 0),
#  datetime.datetime(1974, 9, 2, 0, 0),
#  datetime.datetime(1974, 9, 9, 0, 0),
#  datetime.datetime(1974, 9, 16, 0, 0),
#  datetime.datetime(1974, 9, 23, 0, 0),
#  datetime.datetime(1974, 9, 30, 0, 0),
#  datetime.datetime(1974, 10, 7, 0, 0),
#  datetime.datetime(1974, 10, 14, 0, 0),
#  datetime.datetime(1974, 10, 21, 0, 0),
#  datetime.datetime(1974, 10, 28, 0, 0),
#  datetime.datetime(1974, 11, 4, 0, 0),
#  datetime.datetime(1974, 11, 11, 0, 0),
#  datetime.datetime(1974, 11, 18, 0, 0),
#  datetime.datetime(1974, 11, 25, 0, 0),
#  datetime.datetime(1974, 12, 2, 0, 0),
#  datetime.datetime(1974, 12, 9, 0, 0),
#  datetime.datetime(1974, 12, 16, 0, 0),
#  datetime.datetime(1974, 12, 23, 0, 0),
#  datetime.datetime(1974, 12, 30, 0, 0),
#  datetime.datetime(1975, 1, 6, 0, 0),
#  datetime.datetime(1975, 1, 13, 0, 0),
#  datetime.datetime(1975, 1, 20, 0, 0),
#  datetime.datetime(1975, 1, 27, 0, 0),
#  datetime.datetime(1975, 2, 3, 0, 0),
#  datetime.datetime(1975, 2, 10, 0, 0),
#  datetime.datetime(1975, 2, 17, 0, 0),
#  datetime.datetime(1975, 2, 24, 0, 0),
#  datetime.datetime(1975, 3, 3, 0, 0),
#  datetime.datetime(1975, 3, 10, 0, 0),
#  datetime.datetime(1975, 3, 17, 0, 0),
#  datetime.datetime(1975, 3, 24, 0, 0),
#  datetime.datetime(1975, 3, 31, 0, 0),
#  datetime.datetime(1975, 4, 7, 0, 0),
#  datetime.datetime(1975, 4, 14, 0, 0),
#  datetime.datetime(1975, 4, 21, 0, 0),
#  datetime.datetime(1975, 4, 28, 0, 0),
#  datetime.datetime(1975, 5, 5, 0, 0),
#  datetime.datetime(1975, 5, 12, 0, 0),
#  datetime.datetime(1975, 5, 19, 0, 0),
#  datetime.datetime(1975, 5, 26, 0, 0),
#  datetime.datetime(1975, 6, 2, 0, 0),
#  datetime.datetime(1975, 6, 9, 0, 0),
#  datetime.datetime(1975, 6, 16, 0, 0),
#  datetime.datetime(1975, 6, 23, 0, 0),
#  datetime.datetime(1975, 6, 30, 0, 0),
#  datetime.datetime(1975, 7, 7, 0, 0),
#  datetime.datetime(1975, 7, 14, 0, 0),
#  datetime.datetime(1975, 7, 21, 0, 0),
#  datetime.datetime(1975, 7, 28, 0, 0),
#  datetime.datetime(1975, 8, 4, 0, 0),
#  datetime.datetime(1975, 8, 11, 0, 0),
#  datetime.datetime(1975, 8, 18, 0, 0),
#  datetime.datetime(1975, 8, 25, 0, 0),
#  datetime.datetime(1975, 9, 1, 0, 0),
#  datetime.datetime(1975, 9, 8, 0, 0),
#  datetime.datetime(1975, 9, 15, 0, 0),
#  datetime.datetime(1975, 9, 22, 0, 0),
#  datetime.datetime(1975, 9, 29, 0, 0),
#  datetime.datetime(1975, 10, 6, 0, 0),
#  datetime.datetime(1975, 10, 13, 0, 0),
#  datetime.datetime(1975, 10, 20, 0, 0),
#  datetime.datetime(1975, 10, 27, 0, 0),
#  datetime.datetime(1975, 11, 3, 0, 0),
#  datetime.datetime(1975, 11, 10, 0, 0),
#  datetime.datetime(1975, 11, 17, 0, 0),
#  datetime.datetime(1975, 11, 24, 0, 0),
#  datetime.datetime(1975, 12, 1, 0, 0),
#  datetime.datetime(1975, 12, 8, 0, 0),
#  datetime.datetime(1975, 12, 15, 0, 0),
#  datetime.datetime(1975, 12, 22, 0, 0),
#  datetime.datetime(1975, 12, 29, 0, 0),
#  datetime.datetime(1976, 1, 5, 0, 0),
#  datetime.datetime(1976, 1, 12, 0, 0),
#  datetime.datetime(1976, 1, 19, 0, 0),
#  datetime.datetime(1976, 1, 26, 0, 0),
#  datetime.datetime(1976, 2, 2, 0, 0),
#  datetime.datetime(1976, 2, 9, 0, 0),
#  datetime.datetime(1976, 2, 16, 0, 0),
#  datetime.datetime(1976, 2, 23, 0, 0),
#  datetime.datetime(1976, 3, 1, 0, 0),
#  datetime.datetime(1976, 3, 8, 0, 0),
#  datetime.datetime(1976, 3, 15, 0, 0),
#  datetime.datetime(1976, 3, 22, 0, 0),
#  datetime.datetime(1976, 3, 29, 0, 0),
#  datetime.datetime(1976, 4, 5, 0, 0),
#  datetime.datetime(1976, 4, 12, 0, 0),
#  datetime.datetime(1976, 4, 19, 0, 0),
#  datetime.datetime(1976, 4, 26, 0, 0),
#  datetime.datetime(1976, 5, 3, 0, 0),
#  datetime.datetime(1976, 5, 10, 0, 0),
#  datetime.datetime(1976, 5, 17, 0, 0),
#  datetime.datetime(1976, 5, 24, 0, 0),
#  datetime.datetime(1976, 5, 31, 0, 0),
#  datetime.datetime(1976, 6, 7, 0, 0),
#  datetime.datetime(1976, 6, 14, 0, 0),
#  datetime.datetime(1976, 6, 21, 0, 0),
#  datetime.datetime(1976, 6, 28, 0, 0),
#  datetime.datetime(1976, 7, 5, 0, 0),
#  datetime.datetime(1976, 7, 12, 0, 0),
#  datetime.datetime(1976, 7, 19, 0, 0),
#  datetime.datetime(1976, 7, 26, 0, 0),
#  datetime.datetime(1976, 8, 2, 0, 0),
#  datetime.datetime(1976, 8, 9, 0, 0),
#  datetime.datetime(1976, 8, 16, 0, 0),
#  datetime.datetime(1976, 8, 23, 0, 0),
#  datetime.datetime(1976, 8, 30, 0, 0),
#  datetime.datetime(1976, 9, 6, 0, 0),
#  datetime.datetime(1976, 9, 13, 0, 0),
#  datetime.datetime(1976, 9, 20, 0, 0),
#  datetime.datetime(1976, 9, 27, 0, 0),
#  datetime.datetime(1976, 10, 4, 0, 0),
#  datetime.datetime(1976, 10, 11, 0, 0),
#  datetime.datetime(1976, 10, 18, 0, 0),
#  datetime.datetime(1976, 10, 25, 0, 0),
#  datetime.datetime(1976, 11, 1, 0, 0),
#  datetime.datetime(1976, 11, 8, 0, 0),
#  datetime.datetime(1976, 11, 15, 0, 0),
#  datetime.datetime(1976, 11, 22, 0, 0),
#  datetime.datetime(1976, 11, 29, 0, 0),
#  datetime.datetime(1976, 12, 6, 0, 0),
#  datetime.datetime(1976, 12, 13, 0, 0),
#  datetime.datetime(1976, 12, 20, 0, 0),
#  datetime.datetime(1976, 12, 27, 0, 0),
#  datetime.datetime(1977, 1, 3, 0, 0),
#  datetime.datetime(1977, 1, 10, 0, 0),
#  datetime.datetime(1977, 1, 17, 0, 0),
#  datetime.datetime(1977, 1, 24, 0, 0),
#  datetime.datetime(1977, 1, 31, 0, 0),
#  datetime.datetime(1977, 2, 7, 0, 0),
#  datetime.datetime(1977, 2, 14, 0, 0),
#  datetime.datetime(1977, 2, 21, 0, 0),
#  datetime.datetime(1977, 2, 28, 0, 0),
#  datetime.datetime(1977, 3, 7, 0, 0),
#  datetime.datetime(1977, 3, 14, 0, 0),
#  datetime.datetime(1977, 3, 21, 0, 0),
#  datetime.datetime(1977, 3, 28, 0, 0),
#  datetime.datetime(1977, 4, 4, 0, 0),
#  datetime.datetime(1977, 4, 11, 0, 0),
#  datetime.datetime(1977, 4, 18, 0, 0),
#  datetime.datetime(1977, 4, 25, 0, 0),
#  datetime.datetime(1977, 5, 2, 0, 0),
#  datetime.datetime(1977, 5, 9, 0, 0),
#  datetime.datetime(1977, 5, 16, 0, 0),
#  datetime.datetime(1977, 5, 23, 0, 0),
#  datetime.datetime(1977, 5, 30, 0, 0),
#  datetime.datetime(1977, 6, 6, 0, 0),
#  datetime.datetime(1977, 6, 13, 0, 0),
#  datetime.datetime(1977, 6, 20, 0, 0),
#  datetime.datetime(1977, 6, 27, 0, 0),
#  datetime.datetime(1977, 7, 4, 0, 0),
#  datetime.datetime(1977, 7, 11, 0, 0),
#  datetime.datetime(1977, 7, 18, 0, 0),
#  datetime.datetime(1977, 7, 25, 0, 0),
#  datetime.datetime(1977, 8, 1, 0, 0),
#  datetime.datetime(1977, 8, 8, 0, 0),
#  datetime.datetime(1977, 8, 15, 0, 0),
#  datetime.datetime(1977, 8, 22, 0, 0),
#  datetime.datetime(1977, 8, 29, 0, 0),
#  datetime.datetime(1977, 9, 5, 0, 0),
#  datetime.datetime(1977, 9, 12, 0, 0),
#  datetime.datetime(1977, 9, 19, 0, 0),
#  datetime.datetime(1977, 9, 26, 0, 0),
#  ...]

# %%
# save the date where the download got stop as a new variable

datestop=(datetime.fromisoformat('2015-01-19'))
datestop
# Out:
# datetime.datetime(2015, 1, 19, 0, 0)

# %%
# calculate the dates that are missing and need to be run again

todoDates =[]
for item in formatweekdate:
    if item>datestop:
        todoDates.append(item)
todoDates

#convert them back to strings
todoDates= [date.strftime("%Y-%m-%d") for date in todoDates]

# %%
# rerun the code

Billboard2 =[]
for item in todoDates:
    try:
        # we try to grab all the data, as best we can
        d = {}
        chart= billboard.ChartData('hot-100', date=item)
        d['Date'] = item
        d['Artist'] = chart[0].artist
        d['Song'] = chart[0].title
        d['Weeks'] = chart[0].weeks
        print(d)
        Billboard2.append(d)
    except:
        # if, for any reason at all, it fails - we quickly save the data
        dfBillboard2 = pd.DataFrame(Billboard2)
        dfBillboard2.to_csv('Billboardcharts2.csv', index=False)
        raise
dfBillboard2 = pd.DataFrame(Billboard2)
#save it as a csv
dfBillboard2.to_csv('Billboardcharts2.csv', index=False)
# Out:
# {'Date': '2015-01-26', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 10}
# {'Date': '2015-02-02', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 11}
# {'Date': '2015-02-09', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 12}
# {'Date': '2015-02-16', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 13}
# {'Date': '2015-02-23', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 14}
# {'Date': '2015-03-02', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 15}
# {'Date': '2015-03-09', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 16}
# {'Date': '2015-03-16', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 17}
# {'Date': '2015-03-23', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 18}
# {'Date': '2015-03-30', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 19}
# {'Date': '2015-04-06', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 20}
# {'Date': '2015-04-13', 'Artist': 'Mark Ronson Featuring Bruno Mars', 'Song': 'Uptown Funk!', 'Weeks': 21}
# {'Date': '2015-04-20', 'Artist': 'Wiz Khalifa Featuring Charlie Puth', 'Song': 'See You Again', 'Weeks': 5}
# {'Date': '2015-04-27', 'Artist': 'Wiz Khalifa Featuring Charlie Puth', 'Song': 'See You Again', 'Weeks': 6}
# {'Date': '2015-05-04', 'Artist': 'Wiz Khalifa Featuring Charlie Puth', 'Song': 'See You Again', 'Weeks': 7}
# {'Date': '2015-05-11', 'Artist': 'Wiz Khalifa Featuring Charlie Puth', 'Song': 'See You Again', 'Weeks': 8}
# {'Date': '2021-01-04', 'Artist': '24kGoldn Featuring iann dior', 'Song': 'Mood', 'Weeks': 21}
# {'Date': '2021-01-11', 'Artist': '24kGoldn Featuring iann dior', 'Song': 'Mood', 'Weeks': 22}
# {'Date': '2021-01-18', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 1}
# {'Date': '2021-01-25', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 2}
# {'Date': '2021-02-01', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 3}
# {'Date': '2021-02-08', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 4}
# {'Date': '2021-02-15', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 5}
# {'Date': '2021-02-22', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 6}
# {'Date': '2021-03-01', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 7}
# {'Date': '2021-03-08', 'Artist': 'Olivia Rodrigo', 'Song': 'Drivers License', 'Weeks': 8}
# {'Date': '2021-03-15', 'Artist': 'Drake', 'Song': "What's Next", 'Weeks': 1}
# {'Date': '2021-03-22', 'Artist': 'Cardi B', 'Song': 'Up', 'Weeks': 6}
# {'Date': '2021-03-29', 'Artist': 'Justin Bieber Featuring Daniel Caesar & Giveon', 'Song': 'Peaches', 'Weeks': 1}
# {'Date': '2021-04-05', 'Artist': 'Lil Nas X', 'Song': 'Montero (Call Me By Your Name)', 'Weeks': 1}
# {'Date': '2021-04-12', 'Artist': 'Silk Sonic (Bruno Mars & Anderson .Paak)', 'Song': 'Leave The Door Open', 'Weeks': 5}
# {'Date': '2021-04-19', 'Artist': 'Polo G', 'Song': 'Rapstar', 'Weeks': 1}
# {'Date': '2021-04-26', 'Artist': 'Polo G', 'Song': 'Rapstar', 'Weeks': 2}
# {'Date': '2021-05-03', 'Artist': 'The Weeknd & Ariana Grande', 'Song': 'Save Your Tears', 'Weeks': 20}
# {'Date': '2021-05-10', 'Artist': 'The Weeknd & Ariana Grande', 'Song': 'Save Your Tears', 'Weeks': 21}
# {'Date': '2021-05-17', 'Artist': 'Silk Sonic (Bruno Mars & Anderson .Paak)', 'Song': 'Leave The Door Open', 'Weeks': 10}
# {'Date': '2021-05-24', 'Artist': 'Olivia Rodrigo', 'Song': 'Good 4 U', 'Weeks': 1}
# {'Date': '2021-05-31', 'Artist': 'BTS', 'Song': 'Butter', 'Weeks': 1}
# {'Date': '2021-06-07', 'Artist': 'BTS', 'Song': 'Butter', 'Weeks': 2}
# {'Date': '2021-06-14', 'Artist': 'BTS', 'Song': 'Butter', 'Weeks': 3}
# {'Date': '2021-06-21', 'Artist': 'BTS', 'Song': 'Butter', 'Weeks': 4}
# {'Date': '2021-06-28', 'Artist': 'BTS', 'Song': 'Butter', 'Weeks': 5}
# {'Date': '2021-07-05', 'Artist': 'BTS', 'Song': 'Butter', 'Weeks': 6}
# {'Date': '2021-07-12', 'Artist': 'BTS', 'Song': 'Butter', 'Weeks': 7}

# %%
## append the 2 dataframes and save it as a File

dfBillboard.append(dfBillboard2).to_csv('BillboardchartsFinal.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-225cdf69eec7> in <module>
# ----> 1 dfBillboard2
#
# NameError: name 'dfBillboard2' is not defined

# %% [markdown]
# ## Turn the weekly date into daily data

# %% [markdown]
# Since our Javascript looks compares the entered Birthdays with daily data, it is faster to load in an already completed csv file instead of doing the calculations in Javascript.

# %%
# Import our newly created .csv file

df = pd.read_csv('Billboardcharts.csv')
df.head(10)
# Out:
#         Date            Artist                             Song  Weeks
# 0   8/4/1958      Ricky Nelson                 Poor Little Fool      1
# 1  8/11/1958      Ricky Nelson                 Poor Little Fool      2
# 2  8/18/1958  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 3  8/25/1958      The Elegants                      Little Star      4
# 4   9/1/1958  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      5
# 5   9/8/1958  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      6
# 6  9/15/1958  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      7
# 7  9/22/1958  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      8
# 8  9/29/1958     Tommy Edwards             It's All In The Game      7
# 9  10/6/1958     Tommy Edwards             It's All In The Game      8

# %%
# check if we got all the data we want

df.tail(10)
# Out:
#            Date                                    Artist  \
# 3275 2021-05-10                The Weeknd & Ariana Grande
# 3276 2021-05-17  Silk Sonic (Bruno Mars & Anderson .Paak)
# 3277 2021-05-24                            Olivia Rodrigo
# 3278 2021-05-31                                       BTS
# 3279 2021-06-07                                       BTS
# 3280 2021-06-14                                       BTS
# 3281 2021-06-21                                       BTS
# 3282 2021-06-28                                       BTS
# 3283 2021-07-05                                       BTS
# 3284 2021-07-12                                       BTS
#
#                      Song  Weeks
# 3275      Save Your Tears     21
# 3276  Leave The Door Open     10
# 3277             Good 4 U      1
# 3278               Butter      1
# 3279               Butter      2
# 3280               Butter      3
# 3281               Butter      4
# 3282               Butter      5
# 3283               Butter      6
# 3284               Butter      7

# %%
# turn the Date column into Datetime format

df['Date']= pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3285 entries, 0 to 3284
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3285 non-null   datetime64[ns]
#  1   Artist  3285 non-null   object
#  2   Song    3285 non-null   object
#  3   Weeks   3285 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 102.8+ KB

# %% [markdown]
# Using [resample](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) to turn weekly data into daily data

# %%
# turn the weekly data into daily data

df= df.set_index('Date').resample('1D').ffill().reset_index()

# %%
# check the entries

df.head(30)
# Out:
#          Date            Artist                             Song  Weeks
# 0  1958-08-04      Ricky Nelson                 Poor Little Fool      1
# 1  1958-08-05      Ricky Nelson                 Poor Little Fool      1
# 2  1958-08-06      Ricky Nelson                 Poor Little Fool      1
# 3  1958-08-07      Ricky Nelson                 Poor Little Fool      1
# 4  1958-08-08      Ricky Nelson                 Poor Little Fool      1
# 5  1958-08-09      Ricky Nelson                 Poor Little Fool      1
# 6  1958-08-10      Ricky Nelson                 Poor Little Fool      1
# 7  1958-08-11      Ricky Nelson                 Poor Little Fool      2
# 8  1958-08-12      Ricky Nelson                 Poor Little Fool      2
# 9  1958-08-13      Ricky Nelson                 Poor Little Fool      2
# 10 1958-08-14      Ricky Nelson                 Poor Little Fool      2
# 11 1958-08-15      Ricky Nelson                 Poor Little Fool      2
# 12 1958-08-16      Ricky Nelson                 Poor Little Fool      2
# 13 1958-08-17      Ricky Nelson                 Poor Little Fool      2
# 14 1958-08-18  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 15 1958-08-19  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 16 1958-08-20  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 17 1958-08-21  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 18 1958-08-22  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 19 1958-08-23  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 20 1958-08-24  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      3
# 21 1958-08-25      The Elegants                      Little Star      4
# 22 1958-08-26      The Elegants                      Little Star      4
# 23 1958-08-27      The Elegants                      Little Star      4
# 24 1958-08-28      The Elegants                      Little Star      4
# 25 1958-08-29      The Elegants                      Little Star      4
# 26 1958-08-30      The Elegants                      Little Star      4
# 27 1958-08-31      The Elegants                      Little Star      4
# 28 1958-09-01  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      5
# 29 1958-09-02  Domenico Modugno  Nel Blu Dipinto Di Blu (Volaré)      5

# %% [markdown]
# According to the Python library documentation: The Weeks column, should mean: **The number of weeks the track has been or was on the chart, including future dates (up until the present time).**
#
# However, looking at the data this is not correct!
#
# In my Javascript, I wanted to include a barchart with the Top 10 songs that charted the longest from those Birthday tracks.
# For that I need to recalculate the weekly columns by counting the daily ones and divide them by 7.

# %%
# count how many days each hit has been on the chart

charting=df.Song.value_counts().reset_index()

# %%
# convert the daily charting to how many weeks it has been charting and round the value

charting.Song= round(charting.Song/7)
# Out:
#                      index  Song
# 0            Old Town Road  19.0
# 1            One Sweet Day  16.0
# 2                Despacito  16.0
# 3                 Rockstar  15.0
# 4          I Gotta Feeling  14.0
# ...                    ...   ...
# 1094         Gonna Fly Now   1.0
# 1095            Penny Lane   1.0
# 1096  What A Fool Believes   1.0
# 1097        West End Girls   1.0
# 1098        My Prerogative   1.0
#
# [1099 rows x 2 columns]

# %%
# rename the columns for better merging

charting=charting.rename(columns={"Song": "Week", "index": "Song"})

# %%
# merge it with the original dataset

finaldf=df.merge(charting, how='left', left_on='Song', right_on='Song')

# %%
# drop the wrong Weeks axis

finaldf= finaldf.drop('Weeks',axis=1)

# turn the Week column as an integer
finaldf['Week']=finaldf.Week.astype(int)

# turn the Date column to a string since we turn it into datettime Format in Javascript again
finaldf['Date']=finaldf.Date.astype(str)

# %%
# save the final and cleaned file into a csv

finaldf.to_csv('FinalBillboardCharts.csv', index=False)
